# %% [markdown]
# # Transformer Model
# Training a transformer model to forecast time series sequence of stock closing price
# Using 10 timesteps to forecast 1 forward timestep

# %% [markdown]
# Imports

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import time
import math
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Load data and set global variables

# %%
input_window = 100 # number of input steps
output_window = 1 # number of prediction steps, in this model its fixed to one
batch_size = 128
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

df = pd.read_csv('DST_80.csv') # data path of facebook stock price (Apr 2019 - Nov 2020)
close = df.iloc[1919:, 13:14].values
close = close.squeeze()

mm_scaler = MinMaxScaler()
close = mm_scaler.fit_transform(close.reshape(-1,1))
close = close.squeeze()


logreturn = np.diff(np.log(close)) # Transform closing price to log returns, instead of using min-max scaler
# csum_logreturn = logreturn.cumsum() # Cumulative sum of log returns
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7564\2307988518.py:15: RuntimeWarning: divide by zero encountered in log
#   logreturn = np.diff(np.log(close)) # Transform closing price to log returns, instead of using min-max scaler

# %% [markdown]
# Plot shows the reduced scale of the closing prices

# %%
fig, axs = plt.subplots(2, 1)
axs[0].plot(close, color='red')
axs[0].set_title('Closing Price')
axs[0].set_ylabel('Close Price')
axs[0].set_xlabel('Time Steps')

axs[1].plot(logreturn, color='green')
axs[1].set_title('Cumulative Sum of Log Returns')
axs[1].set_xlabel('Time Steps')

fig.tight_layout()
plt.show()

# %% [markdown]
# Positional Encoder

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()       
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]

# %% [markdown]
# Transformer Model

# %%
class TransAm(nn.Module):
    def __init__(self, feature_size=250, num_layers=4, dropout=0.1):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'
        
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)        
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.pos_encoder(src)
        output = self.transformer_encoder(src,self.src_mask)
        output = self.decoder(output)
        return output

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

# %% [markdown]
# Window function, split data into sequence window

# %%
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+output_window:i+tw+output_window]
        inout_seq.append((train_seq ,train_label))
    return torch.FloatTensor(inout_seq)

# %% [markdown]
# Split data in training and testing, prepared in windowed sequences and pass through GPU

# %%
def get_data(data, split):
    """Split ratio of training data"""

    series = data
    
    split = round(split*len(series))
    train_data = series[:split]
    test_data = series[split:]

    # train_data = train_data.cumsum()
    # train_data = 2*train_data # Training data augmentation, increase amplitude for the model to better generalize.(Scaling by 2 is aribitrary)
    #                           # Similar to image transformation to allow model to train on wider data sets

    # test_data = test_data.cumsum()

    train_sequence = create_inout_sequences(train_data,input_window)
    train_sequence = train_sequence[:-output_window]

    test_data = create_inout_sequences(test_data,input_window)
    test_data = test_data[:-output_window]

    return train_sequence.to(device), test_data.to(device)

# %% [markdown]
# Split into training batches

# %%
def get_batch(source, i, batch_size):
    seq_len = min(batch_size, len(source) - 1 - i)
    data = source[i:i+seq_len]    
    input = torch.stack(torch.stack([item[0] for item in data]).chunk(input_window, 1))
    target = torch.stack(torch.stack([item[1] for item in data]).chunk(input_window, 1))
    return input, target

# %% [markdown]
# Training function

# %%
def train(train_data):
    model.train() # Turn on the evaluation mode
    total_loss = 0.
    start_time = time.time()

    for batch, i in enumerate(range(0, len(train_data) - 1, batch_size)):
        data, targets = get_batch(train_data, i,batch_size)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.7)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_data) / batch_size / 10)
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.10f} | {:5.2f} ms | '
                  'loss {:5.7f}'.format(
                    epoch, batch, len(train_data) // batch_size, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss))
            total_loss = 0
            start_time = time.time()

# %% [markdown]
# Evaluation function for model after training

# %%
criterion = nn.MSELoss() # Loss function

# %%
def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    eval_batch_size = 128
    with torch.no_grad():
        for i in range(0, len(data_source) - 1, eval_batch_size):
        # for i in range(0, len(data_source) - 1, eval_batch_size):
            data, targets = get_batch(data_source, i, eval_batch_size)
            output = eval_model(data)
            total_loss += len(data[0])* criterion(output, targets).cpu().item()

    return total_loss / len(data_source)

# %% [markdown]
# Function to forecast 1 time step from window sequence

# %%
def model_forecast(model, seqence):
    model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)

    seq = np.pad(seqence, (0, 3), mode='constant', constant_values=(0, 0))
    seq = create_inout_sequences(seq, input_window)
    seq = seq[:-output_window].to(device)

    seq, _ = get_batch(seq, 0, 1)
    with torch.no_grad():
        for i in range(0, output_window):            
            output = model(seq[-output_window:])                        
            seq = torch.cat((seq, output[-1:]))

    seq = seq.cpu().view(-1).numpy()

    return seq

# %% [markdown]
# Function to forecast entire sequence

# %%
def forecast_seq(model, sequences):
    """Sequences data has to been windowed and passed through device"""
    start_timer = time.time()
    model.eval()
    forecast_seq = torch.Tensor(0)    
    actual = torch.Tensor(0)
    with torch.no_grad():
        for i in range(0, len(sequences) - 1):
            data, target = get_batch(sequences, i, 1)
            output = model(data)            
            forecast_seq = torch.cat((forecast_seq, output[-1].view(-1).cpu()), 0)
            actual = torch.cat((actual, target[-1].view(-1).cpu()), 0)
    timed = time.time()-start_timer
    print(f"{timed} sec")

    return forecast_seq, actual

# %% [markdown]
# Prepare data for training model

# %%
train_data, val_data = get_data(close, 1.0) # 60% train, 40% test split
model = TransAm().to(device)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7564\219410700.py:8: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   return torch.FloatTensor(inout_seq)

# %% [markdown]
# Model parameters

# %%
#criterion = nn.MSELoss() # Loss function
lr = 0.00005 # learning rate

optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

epochs =  100 # Number of epochs

# %% [markdown]
# Training loop

# %%
for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(train_data)
    
    if(epoch % epochs == 0): # Valid model after last training epoch
        val_loss = evaluate(model, train_data)
        print('-' * 80)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss: {:5.7f}'.format(epoch, (time.time() - epoch_start_time), val_loss))
        print('-' * 80)

    else:   
        print('-' * 80)
        print('| end of epoch {:3d} | time: {:5.2f}s'.format(epoch, (time.time() - epoch_start_time)))
        print('-' * 80)

    scheduler.step()
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:389: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | epoch   1 |     8/   82 batches | lr 0.0000500000 | 619.64 ms | loss 0.9135976
# | epoch   1 |    16/   82 batches | lr 0.0000500000 | 120.87 ms | loss 0.2920026
# | epoch   1 |    24/   82 batches | lr 0.0000500000 | 122.19 ms | loss 0.1281845
# | epoch   1 |    32/   82 batches | lr 0.0000500000 | 120.80 ms | loss 0.0703526
# | epoch   1 |    40/   82 batches | lr 0.0000500000 | 121.72 ms | loss 0.0453331
# | epoch   1 |    48/   82 batches | lr 0.0000500000 | 121.62 ms | loss 0.0356901
# | epoch   1 |    56/   82 batches | lr 0.0000500000 | 121.90 ms | loss 0.0296311
# | epoch   1 |    64/   82 batches | lr 0.0000500000 | 122.13 ms | loss 0.0273241
# | epoch   1 |    72/   82 batches | lr 0.0000500000 | 121.25 ms | loss 0.0254186
# | epoch   1 |    80/   82 batches | lr 0.0000500000 | 118.63 ms | loss 0.0237609
# --------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.86s
# --------------------------------------------------------------------------------
# | epoch   2 |     8/   82 batches | lr 0.0000451250 | 133.75 ms | loss 0.3264934
# | epoch   2 |    16/   82 batches | lr 0.0000451250 | 118.88 ms | loss 0.0958362
# | epoch   2 |    24/   82 batches | lr 0.0000451250 | 119.88 ms | loss 0.0574426
# | epoch   2 |    32/   82 batches | lr 0.0000451250 | 120.36 ms | loss 0.0352789
# | epoch   2 |    40/   82 batches | lr 0.0000451250 | 121.93 ms | loss 0.0275474
# | epoch   2 |    48/   82 batches | lr 0.0000451250 | 119.63 ms | loss 0.0216292
# | epoch   2 |    56/   82 batches | lr 0.0000451250 | 119.25 ms | loss 0.0192158
# | epoch   2 |    64/   82 batches | lr 0.0000451250 | 121.75 ms | loss 0.0179577
# | epoch   2 |    72/   82 batches | lr 0.0000451250 | 122.12 ms | loss 0.0171278
# | epoch   2 |    80/   82 batches | lr 0.0000451250 | 122.25 ms | loss 0.0166041
# --------------------------------------------------------------------------------
# | end of epoch   2 | time:  9.92s
# --------------------------------------------------------------------------------
# | epoch   3 |     8/   82 batches | lr 0.0000428687 | 135.75 ms | loss 0.2922534
# | epoch   3 |    16/   82 batches | lr 0.0000428687 | 120.74 ms | loss 0.0859524
# | epoch   3 |    24/   82 batches | lr 0.0000428687 | 121.88 ms | loss 0.0473314
# | epoch   3 |    32/   82 batches | lr 0.0000428687 | 121.41 ms | loss 0.0262184
# | epoch   3 |    40/   82 batches | lr 0.0000428687 | 120.15 ms | loss 0.0204081
# | epoch   3 |    48/   82 batches | lr 0.0000428687 | 121.50 ms | loss 0.0153266
# | epoch   3 |    56/   82 batches | lr 0.0000428687 | 120.88 ms | loss 0.0144432
# | epoch   3 |    64/   82 batches | lr 0.0000428687 | 121.87 ms | loss 0.0131368
# | epoch   3 |    72/   82 batches | lr 0.0000428687 | 121.63 ms | loss 0.0127799
# | epoch   3 |    80/   82 batches | lr 0.0000428687 | 122.12 ms | loss 0.0122991
# --------------------------------------------------------------------------------
# | end of epoch   3 | time:  9.99s
# --------------------------------------------------------------------------------
# | epoch   4 |     8/   82 batches | lr 0.0000407253 | 136.74 ms | loss 0.2907099
# | epoch   4 |    16/   82 batches | lr 0.0000407253 | 123.77 ms | loss 0.0879115
# | epoch   4 |    24/   82 batches | lr 0.0000407253 | 127.91 ms | loss 0.0441583
# | epoch   4 |    32/   82 batches | lr 0.0000407253 | 124.76 ms | loss 0.0250820
# | epoch   4 |    40/   82 batches | lr 0.0000407253 | 128.28 ms | loss 0.0169934
# | epoch   4 |    48/   82 batches | lr 0.0000407253 | 132.93 ms | loss 0.0135231
# | epoch   4 |    56/   82 batches | lr 0.0000407253 | 136.29 ms | loss 0.0112750
# | epoch   4 |    64/   82 batches | lr 0.0000407253 | 134.07 ms | loss 0.0106832
# | epoch   4 |    72/   82 batches | lr 0.0000407253 | 134.80 ms | loss 0.0100500
# | epoch   4 |    80/   82 batches | lr 0.0000407253 | 133.60 ms | loss 0.0097473
# --------------------------------------------------------------------------------
# | end of epoch   4 | time: 10.69s
# --------------------------------------------------------------------------------
# | epoch   5 |     8/   82 batches | lr 0.0000386890 | 148.59 ms | loss 0.2716930
# | epoch   5 |    16/   82 batches | lr 0.0000386890 | 132.30 ms | loss 0.0909840
# | epoch   5 |    24/   82 batches | lr 0.0000386890 | 131.58 ms | loss 0.0450979
# | epoch   5 |    32/   82 batches | lr 0.0000386890 | 133.88 ms | loss 0.0288909
# | epoch   5 |    40/   82 batches | lr 0.0000386890 | 132.90 ms | loss 0.0150701
# | epoch   5 |    48/   82 batches | lr 0.0000386890 | 132.26 ms | loss 0.0123527
# | epoch   5 |    56/   82 batches | lr 0.0000386890 | 132.60 ms | loss 0.0089658
# | epoch   5 |    64/   82 batches | lr 0.0000386890 | 132.01 ms | loss 0.0087752
# | epoch   5 |    72/   82 batches | lr 0.0000386890 | 132.52 ms | loss 0.0081450
# | epoch   5 |    80/   82 batches | lr 0.0000386890 | 131.58 ms | loss 0.0080572
# --------------------------------------------------------------------------------
# | end of epoch   5 | time: 10.90s
# --------------------------------------------------------------------------------
# | epoch   6 |     8/   82 batches | lr 0.0000367546 | 146.55 ms | loss 0.2683029
# | epoch   6 |    16/   82 batches | lr 0.0000367546 | 131.38 ms | loss 0.1067570
# | epoch   6 |    24/   82 batches | lr 0.0000367546 | 130.59 ms | loss 0.0501978
# | epoch   6 |    32/   82 batches | lr 0.0000367546 | 130.41 ms | loss 0.0282639
# | epoch   6 |    40/   82 batches | lr 0.0000367546 | 130.89 ms | loss 0.0115640
# | epoch   6 |    48/   82 batches | lr 0.0000367546 | 130.70 ms | loss 0.0092593
# | epoch   6 |    56/   82 batches | lr 0.0000367546 | 131.05 ms | loss 0.0086913
# | epoch   6 |    64/   82 batches | lr 0.0000367546 | 130.95 ms | loss 0.0071948
# | epoch   6 |    72/   82 batches | lr 0.0000367546 | 130.45 ms | loss 0.0072684
# | epoch   6 |    80/   82 batches | lr 0.0000367546 | 130.37 ms | loss 0.0067236
# --------------------------------------------------------------------------------
# | end of epoch   6 | time: 10.77s
# --------------------------------------------------------------------------------
# | epoch   7 |     8/   82 batches | lr 0.0000349169 | 146.80 ms | loss 0.2505717
# | epoch   7 |    16/   82 batches | lr 0.0000349169 | 130.79 ms | loss 0.1204029
# | epoch   7 |    24/   82 batches | lr 0.0000349169 | 130.89 ms | loss 0.0459464
# | epoch   7 |    32/   82 batches | lr 0.0000349169 | 130.47 ms | loss 0.0199004
# | epoch   7 |    40/   82 batches | lr 0.0000349169 | 132.02 ms | loss 0.0120955
# | epoch   7 |    48/   82 batches | lr 0.0000349169 | 130.53 ms | loss 0.0086009
# | epoch   7 |    56/   82 batches | lr 0.0000349169 | 130.87 ms | loss 0.0083769
# | epoch   7 |    64/   82 batches | lr 0.0000349169 | 130.26 ms | loss 0.0061331
# | epoch   7 |    72/   82 batches | lr 0.0000349169 | 131.25 ms | loss 0.0060877
# | epoch   7 |    80/   82 batches | lr 0.0000349169 | 130.75 ms | loss 0.0061075
# --------------------------------------------------------------------------------
# | end of epoch   7 | time: 10.77s
# --------------------------------------------------------------------------------
# | epoch   8 |     8/   82 batches | lr 0.0000331710 | 147.26 ms | loss 0.2632479
# | epoch   8 |    16/   82 batches | lr 0.0000331710 | 131.11 ms | loss 0.1412954
# | epoch   8 |    24/   82 batches | lr 0.0000331710 | 130.93 ms | loss 0.0367885
# | epoch   8 |    32/   82 batches | lr 0.0000331710 | 130.40 ms | loss 0.0155920
# | epoch   8 |    40/   82 batches | lr 0.0000331710 | 130.53 ms | loss 0.0172490
# | epoch   8 |    48/   82 batches | lr 0.0000331710 | 130.83 ms | loss 0.0074129
# | epoch   8 |    56/   82 batches | lr 0.0000331710 | 130.09 ms | loss 0.0063140
# | epoch   8 |    64/   82 batches | lr 0.0000331710 | 131.23 ms | loss 0.0063334
# | epoch   8 |    72/   82 batches | lr 0.0000331710 | 130.47 ms | loss 0.0052064
# | epoch   8 |    80/   82 batches | lr 0.0000331710 | 131.13 ms | loss 0.0054363
# --------------------------------------------------------------------------------
# | end of epoch   8 | time: 10.77s
# --------------------------------------------------------------------------------
# | epoch   9 |     8/   82 batches | lr 0.0000315125 | 146.61 ms | loss 0.2628256
# | epoch   9 |    16/   82 batches | lr 0.0000315125 | 131.82 ms | loss 0.1445909
# | epoch   9 |    24/   82 batches | lr 0.0000315125 | 130.76 ms | loss 0.0255431
# | epoch   9 |    32/   82 batches | lr 0.0000315125 | 130.74 ms | loss 0.0177477
# | epoch   9 |    40/   82 batches | lr 0.0000315125 | 130.11 ms | loss 0.0177547
# | epoch   9 |    48/   82 batches | lr 0.0000315125 | 131.53 ms | loss 0.0062330
# | epoch   9 |    56/   82 batches | lr 0.0000315125 | 129.86 ms | loss 0.0054099
# | epoch   9 |    64/   82 batches | lr 0.0000315125 | 130.95 ms | loss 0.0062274
# | epoch   9 |    72/   82 batches | lr 0.0000315125 | 131.12 ms | loss 0.0047828
# | epoch   9 |    80/   82 batches | lr 0.0000315125 | 132.06 ms | loss 0.0047654
# --------------------------------------------------------------------------------
# | end of epoch   9 | time: 10.78s
# --------------------------------------------------------------------------------
# | epoch  10 |     8/   82 batches | lr 0.0000299368 | 147.98 ms | loss 0.2567578
# | epoch  10 |    16/   82 batches | lr 0.0000299368 | 130.82 ms | loss 0.1369645
# | epoch  10 |    24/   82 batches | lr 0.0000299368 | 131.30 ms | loss 0.0208466
# | epoch  10 |    32/   82 batches | lr 0.0000299368 | 130.89 ms | loss 0.0210899
# | epoch  10 |    40/   82 batches | lr 0.0000299368 | 131.19 ms | loss 0.0134159
# | epoch  10 |    48/   82 batches | lr 0.0000299368 | 132.31 ms | loss 0.0075860
# | epoch  10 |    56/   82 batches | lr 0.0000299368 | 132.86 ms | loss 0.0049768
# | epoch  10 |    64/   82 batches | lr 0.0000299368 | 132.40 ms | loss 0.0050336
# | epoch  10 |    72/   82 batches | lr 0.0000299368 | 120.25 ms | loss 0.0049313
# | epoch  10 |    80/   82 batches | lr 0.0000299368 | 118.50 ms | loss 0.0042798
# --------------------------------------------------------------------------------
# | end of epoch  10 | time: 10.63s
# --------------------------------------------------------------------------------
# | epoch  11 |     8/   82 batches | lr 0.0000284400 | 134.12 ms | loss 0.2637576
# | epoch  11 |    16/   82 batches | lr 0.0000284400 | 118.63 ms | loss 0.1299174
# | epoch  11 |    24/   82 batches | lr 0.0000284400 | 119.00 ms | loss 0.0240394
# | epoch  11 |    32/   82 batches | lr 0.0000284400 | 119.25 ms | loss 0.0222081
# | epoch  11 |    40/   82 batches | lr 0.0000284400 | 125.80 ms | loss 0.0089859
# | epoch  11 |    48/   82 batches | lr 0.0000284400 | 124.97 ms | loss 0.0102937
# | epoch  11 |    56/   82 batches | lr 0.0000284400 | 133.59 ms | loss 0.0043202
# | epoch  11 |    64/   82 batches | lr 0.0000284400 | 132.66 ms | loss 0.0041328
# | epoch  11 |    72/   82 batches | lr 0.0000284400 | 131.53 ms | loss 0.0049087
# | epoch  11 |    80/   82 batches | lr 0.0000284400 | 131.37 ms | loss 0.0040150
# --------------------------------------------------------------------------------
# | end of epoch  11 | time: 10.35s
# --------------------------------------------------------------------------------
# | epoch  12 |     8/   82 batches | lr 0.0000270180 | 147.83 ms | loss 0.2786069
# | epoch  12 |    16/   82 batches | lr 0.0000270180 | 131.13 ms | loss 0.1189402
# | epoch  12 |    24/   82 batches | lr 0.0000270180 | 131.41 ms | loss 0.0334383
# | epoch  12 |    32/   82 batches | lr 0.0000270180 | 131.50 ms | loss 0.0202453
# | epoch  12 |    40/   82 batches | lr 0.0000270180 | 131.42 ms | loss 0.0067190
# | epoch  12 |    48/   82 batches | lr 0.0000270180 | 131.17 ms | loss 0.0116136
# | epoch  12 |    56/   82 batches | lr 0.0000270180 | 129.03 ms | loss 0.0042779
# | epoch  12 |    64/   82 batches | lr 0.0000270180 | 127.76 ms | loss 0.0038588
# | epoch  12 |    72/   82 batches | lr 0.0000270180 | 128.49 ms | loss 0.0043758
# | epoch  12 |    80/   82 batches | lr 0.0000270180 | 128.35 ms | loss 0.0039645
# --------------------------------------------------------------------------------
# | end of epoch  12 | time: 10.72s
# --------------------------------------------------------------------------------
# | epoch  13 |     8/   82 batches | lr 0.0000256671 | 144.66 ms | loss 0.2833764
# | epoch  13 |    16/   82 batches | lr 0.0000256671 | 128.83 ms | loss 0.1011536
# | epoch  13 |    24/   82 batches | lr 0.0000256671 | 130.43 ms | loss 0.0450190
# | epoch  13 |    32/   82 batches | lr 0.0000256671 | 131.62 ms | loss 0.0153474
# | epoch  13 |    40/   82 batches | lr 0.0000256671 | 131.34 ms | loss 0.0067451
# | epoch  13 |    48/   82 batches | lr 0.0000256671 | 131.44 ms | loss 0.0103937
# | epoch  13 |    56/   82 batches | lr 0.0000256671 | 131.03 ms | loss 0.0052301
# | epoch  13 |    64/   82 batches | lr 0.0000256671 | 129.66 ms | loss 0.0035860
# | epoch  13 |    72/   82 batches | lr 0.0000256671 | 131.22 ms | loss 0.0037671
# | epoch  13 |    80/   82 batches | lr 0.0000256671 | 130.55 ms | loss 0.0039716
# --------------------------------------------------------------------------------
# | end of epoch  13 | time: 10.74s
# --------------------------------------------------------------------------------
# | epoch  14 |     8/   82 batches | lr 0.0000243837 | 146.67 ms | loss 0.2804962
# | epoch  14 |    16/   82 batches | lr 0.0000243837 | 130.26 ms | loss 0.0834817
# | epoch  14 |    24/   82 batches | lr 0.0000243837 | 132.89 ms | loss 0.0537404
# | epoch  14 |    32/   82 batches | lr 0.0000243837 | 128.89 ms | loss 0.0112352
# | epoch  14 |    40/   82 batches | lr 0.0000243837 | 128.46 ms | loss 0.0073981
# | epoch  14 |    48/   82 batches | lr 0.0000243837 | 132.42 ms | loss 0.0084769
# | epoch  14 |    56/   82 batches | lr 0.0000243837 | 123.38 ms | loss 0.0058215
# | epoch  14 |    64/   82 batches | lr 0.0000243837 | 122.72 ms | loss 0.0034308
# | epoch  14 |    72/   82 batches | lr 0.0000243837 | 120.50 ms | loss 0.0034982
# | epoch  14 |    80/   82 batches | lr 0.0000243837 | 118.88 ms | loss 0.0037857
# --------------------------------------------------------------------------------
# | end of epoch  14 | time: 10.45s
# --------------------------------------------------------------------------------
# | epoch  15 |     8/   82 batches | lr 0.0000231646 | 135.75 ms | loss 0.2536579
# | epoch  15 |    16/   82 batches | lr 0.0000231646 | 119.00 ms | loss 0.0660806
# | epoch  15 |    24/   82 batches | lr 0.0000231646 | 118.87 ms | loss 0.0558437
# | epoch  15 |    32/   82 batches | lr 0.0000231646 | 120.37 ms | loss 0.0077118
# | epoch  15 |    40/   82 batches | lr 0.0000231646 | 120.50 ms | loss 0.0075608
# | epoch  15 |    48/   82 batches | lr 0.0000231646 | 118.62 ms | loss 0.0064721
# | epoch  15 |    56/   82 batches | lr 0.0000231646 | 119.25 ms | loss 0.0065368
# | epoch  15 |    64/   82 batches | lr 0.0000231646 | 120.63 ms | loss 0.0033902
# | epoch  15 |    72/   82 batches | lr 0.0000231646 | 121.87 ms | loss 0.0033609
# | epoch  15 |    80/   82 batches | lr 0.0000231646 | 119.88 ms | loss 0.0036821
# --------------------------------------------------------------------------------
# | end of epoch  15 | time:  9.88s
# --------------------------------------------------------------------------------
# | epoch  16 |     8/   82 batches | lr 0.0000220063 | 135.37 ms | loss 0.2538066
# | epoch  16 |    16/   82 batches | lr 0.0000220063 | 118.12 ms | loss 0.0564897
# | epoch  16 |    24/   82 batches | lr 0.0000220063 | 119.00 ms | loss 0.0599226
# | epoch  16 |    32/   82 batches | lr 0.0000220063 | 122.13 ms | loss 0.0067167
# | epoch  16 |    40/   82 batches | lr 0.0000220063 | 124.75 ms | loss 0.0079413
# | epoch  16 |    48/   82 batches | lr 0.0000220063 | 121.87 ms | loss 0.0053302
# | epoch  16 |    56/   82 batches | lr 0.0000220063 | 123.00 ms | loss 0.0062007
# | epoch  16 |    64/   82 batches | lr 0.0000220063 | 120.25 ms | loss 0.0032499
# | epoch  16 |    72/   82 batches | lr 0.0000220063 | 123.37 ms | loss 0.0032802
# | epoch  16 |    80/   82 batches | lr 0.0000220063 | 122.50 ms | loss 0.0035387
# --------------------------------------------------------------------------------
# | end of epoch  16 | time: 10.01s
# --------------------------------------------------------------------------------
# | epoch  17 |     8/   82 batches | lr 0.0000209060 | 138.50 ms | loss 0.2110886
# | epoch  17 |    16/   82 batches | lr 0.0000209060 | 122.63 ms | loss 0.0443234
# | epoch  17 |    24/   82 batches | lr 0.0000209060 | 123.22 ms | loss 0.0566986
# | epoch  17 |    32/   82 batches | lr 0.0000209060 | 122.88 ms | loss 0.0059230
# | epoch  17 |    40/   82 batches | lr 0.0000209060 | 123.00 ms | loss 0.0067272
# | epoch  17 |    48/   82 batches | lr 0.0000209060 | 122.62 ms | loss 0.0039345
# | epoch  17 |    56/   82 batches | lr 0.0000209060 | 123.00 ms | loss 0.0061815
# | epoch  17 |    64/   82 batches | lr 0.0000209060 | 121.88 ms | loss 0.0033945
# | epoch  17 |    72/   82 batches | lr 0.0000209060 | 119.25 ms | loss 0.0032580
# | epoch  17 |    80/   82 batches | lr 0.0000209060 | 120.88 ms | loss 0.0033764
# --------------------------------------------------------------------------------
# | end of epoch  17 | time: 10.07s
# --------------------------------------------------------------------------------
# | epoch  18 |     8/   82 batches | lr 0.0000198607 | 136.75 ms | loss 0.2199106
# | epoch  18 |    16/   82 batches | lr 0.0000198607 | 119.38 ms | loss 0.0374195
# | epoch  18 |    24/   82 batches | lr 0.0000198607 | 121.75 ms | loss 0.0608595
# | epoch  18 |    32/   82 batches | lr 0.0000198607 | 121.75 ms | loss 0.0069732
# | epoch  18 |    40/   82 batches | lr 0.0000198607 | 118.75 ms | loss 0.0071737
# | epoch  18 |    48/   82 batches | lr 0.0000198607 | 119.00 ms | loss 0.0036046
# | epoch  18 |    56/   82 batches | lr 0.0000198607 | 118.62 ms | loss 0.0055706
# | epoch  18 |    64/   82 batches | lr 0.0000198607 | 118.88 ms | loss 0.0032138
# | epoch  18 |    72/   82 batches | lr 0.0000198607 | 118.88 ms | loss 0.0032539
# | epoch  18 |    80/   82 batches | lr 0.0000198607 | 119.12 ms | loss 0.0033923
# --------------------------------------------------------------------------------
# | end of epoch  18 | time:  9.87s
# --------------------------------------------------------------------------------
# | epoch  19 |     8/   82 batches | lr 0.0000188677 | 133.75 ms | loss 0.1752248
# | epoch  19 |    16/   82 batches | lr 0.0000188677 | 119.25 ms | loss 0.0291028
# | epoch  19 |    24/   82 batches | lr 0.0000188677 | 119.00 ms | loss 0.0530968
# | epoch  19 |    32/   82 batches | lr 0.0000188677 | 118.87 ms | loss 0.0075672
# | epoch  19 |    40/   82 batches | lr 0.0000188677 | 119.00 ms | loss 0.0054181
# | epoch  19 |    48/   82 batches | lr 0.0000188677 | 119.06 ms | loss 0.0032099
# | epoch  19 |    56/   82 batches | lr 0.0000188677 | 118.63 ms | loss 0.0048053
# | epoch  19 |    64/   82 batches | lr 0.0000188677 | 120.56 ms | loss 0.0032100
# | epoch  19 |    72/   82 batches | lr 0.0000188677 | 120.63 ms | loss 0.0032143
# | epoch  19 |    80/   82 batches | lr 0.0000188677 | 121.37 ms | loss 0.0032307
# --------------------------------------------------------------------------------
# | end of epoch  19 | time:  9.85s
# --------------------------------------------------------------------------------
# | epoch  20 |     8/   82 batches | lr 0.0000179243 | 136.62 ms | loss 0.1709888
# | epoch  20 |    16/   82 batches | lr 0.0000179243 | 120.00 ms | loss 0.0250551
# | epoch  20 |    24/   82 batches | lr 0.0000179243 | 120.37 ms | loss 0.0520694
# | epoch  20 |    32/   82 batches | lr 0.0000179243 | 123.13 ms | loss 0.0084772
# | epoch  20 |    40/   82 batches | lr 0.0000179243 | 123.63 ms | loss 0.0055825
# | epoch  20 |    48/   82 batches | lr 0.0000179243 | 123.12 ms | loss 0.0032618
# | epoch  20 |    56/   82 batches | lr 0.0000179243 | 122.38 ms | loss 0.0045142
# | epoch  20 |    64/   82 batches | lr 0.0000179243 | 122.26 ms | loss 0.0030940
# | epoch  20 |    72/   82 batches | lr 0.0000179243 | 122.00 ms | loss 0.0031615
# | epoch  20 |    80/   82 batches | lr 0.0000179243 | 122.38 ms | loss 0.0032016
# --------------------------------------------------------------------------------
# | end of epoch  20 | time: 10.05s
# --------------------------------------------------------------------------------
# | epoch  21 |     8/   82 batches | lr 0.0000170281 | 137.88 ms | loss 0.1447963
# | epoch  21 |    16/   82 batches | lr 0.0000170281 | 122.06 ms | loss 0.0209721
# | epoch  21 |    24/   82 batches | lr 0.0000170281 | 122.13 ms | loss 0.0466819
# | epoch  21 |    32/   82 batches | lr 0.0000170281 | 119.95 ms | loss 0.0091495
# | epoch  21 |    40/   82 batches | lr 0.0000170281 | 118.62 ms | loss 0.0045837
# | epoch  21 |    48/   82 batches | lr 0.0000170281 | 119.07 ms | loss 0.0031193
# | epoch  21 |    56/   82 batches | lr 0.0000170281 | 119.25 ms | loss 0.0039650
# | epoch  21 |    64/   82 batches | lr 0.0000170281 | 119.25 ms | loss 0.0030038
# | epoch  21 |    72/   82 batches | lr 0.0000170281 | 121.37 ms | loss 0.0030408
# | epoch  21 |    80/   82 batches | lr 0.0000170281 | 121.00 ms | loss 0.0030989
# --------------------------------------------------------------------------------
# | end of epoch  21 | time:  9.93s
# --------------------------------------------------------------------------------
# | epoch  22 |     8/   82 batches | lr 0.0000161767 | 138.50 ms | loss 0.1397485
# | epoch  22 |    16/   82 batches | lr 0.0000161767 | 119.63 ms | loss 0.0185394
# | epoch  22 |    24/   82 batches | lr 0.0000161767 | 118.88 ms | loss 0.0450856
# | epoch  22 |    32/   82 batches | lr 0.0000161767 | 121.87 ms | loss 0.0099681
# | epoch  22 |    40/   82 batches | lr 0.0000161767 | 121.88 ms | loss 0.0044760
# | epoch  22 |    48/   82 batches | lr 0.0000161767 | 121.50 ms | loss 0.0031921
# | epoch  22 |    56/   82 batches | lr 0.0000161767 | 121.62 ms | loss 0.0038421
# | epoch  22 |    64/   82 batches | lr 0.0000161767 | 120.13 ms | loss 0.0029647
# | epoch  22 |    72/   82 batches | lr 0.0000161767 | 120.88 ms | loss 0.0030208
# | epoch  22 |    80/   82 batches | lr 0.0000161767 | 120.62 ms | loss 0.0030469
# --------------------------------------------------------------------------------
# | end of epoch  22 | time:  9.97s
# --------------------------------------------------------------------------------
# | epoch  23 |     8/   82 batches | lr 0.0000153678 | 136.87 ms | loss 0.1265972
# | epoch  23 |    16/   82 batches | lr 0.0000153678 | 118.63 ms | loss 0.0163672
# | epoch  23 |    24/   82 batches | lr 0.0000153678 | 120.00 ms | loss 0.0420096
# | epoch  23 |    32/   82 batches | lr 0.0000153678 | 120.87 ms | loss 0.0105344
# | epoch  23 |    40/   82 batches | lr 0.0000153678 | 121.00 ms | loss 0.0040931
# | epoch  23 |    48/   82 batches | lr 0.0000153678 | 119.12 ms | loss 0.0031789
# | epoch  23 |    56/   82 batches | lr 0.0000153678 | 119.00 ms | loss 0.0035327
# | epoch  23 |    64/   82 batches | lr 0.0000153678 | 120.87 ms | loss 0.0029220
# | epoch  23 |    72/   82 batches | lr 0.0000153678 | 122.62 ms | loss 0.0029493
# | epoch  23 |    80/   82 batches | lr 0.0000153678 | 120.00 ms | loss 0.0030289
# --------------------------------------------------------------------------------
# | end of epoch  23 | time:  9.92s
# --------------------------------------------------------------------------------
# | epoch  24 |     8/   82 batches | lr 0.0000145995 | 133.50 ms | loss 0.1210679
# | epoch  24 |    16/   82 batches | lr 0.0000145995 | 119.37 ms | loss 0.0148013
# | epoch  24 |    24/   82 batches | lr 0.0000145995 | 120.25 ms | loss 0.0401210
# | epoch  24 |    32/   82 batches | lr 0.0000145995 | 120.36 ms | loss 0.0111163
# | epoch  24 |    40/   82 batches | lr 0.0000145995 | 119.13 ms | loss 0.0038540
# | epoch  24 |    48/   82 batches | lr 0.0000145995 | 119.63 ms | loss 0.0031892
# | epoch  24 |    56/   82 batches | lr 0.0000145995 | 118.94 ms | loss 0.0033886
# | epoch  24 |    64/   82 batches | lr 0.0000145995 | 119.12 ms | loss 0.0028630
# | epoch  24 |    72/   82 batches | lr 0.0000145995 | 119.75 ms | loss 0.0028886
# | epoch  24 |    80/   82 batches | lr 0.0000145995 | 121.50 ms | loss 0.0029375
# --------------------------------------------------------------------------------
# | end of epoch  24 | time:  9.86s
# --------------------------------------------------------------------------------
# | epoch  25 |     8/   82 batches | lr 0.0000138695 | 133.50 ms | loss 0.1142665
# | epoch  25 |    16/   82 batches | lr 0.0000138695 | 119.38 ms | loss 0.0133335
# | epoch  25 |    24/   82 batches | lr 0.0000138695 | 118.75 ms | loss 0.0379417
# | epoch  25 |    32/   82 batches | lr 0.0000138695 | 119.88 ms | loss 0.0114986
# | epoch  25 |    40/   82 batches | lr 0.0000138695 | 119.00 ms | loss 0.0037658
# | epoch  25 |    48/   82 batches | lr 0.0000138695 | 119.38 ms | loss 0.0032849
# | epoch  25 |    56/   82 batches | lr 0.0000138695 | 118.92 ms | loss 0.0032598
# | epoch  25 |    64/   82 batches | lr 0.0000138695 | 119.62 ms | loss 0.0027969
# | epoch  25 |    72/   82 batches | lr 0.0000138695 | 119.45 ms | loss 0.0028210
# | epoch  25 |    80/   82 batches | lr 0.0000138695 | 118.62 ms | loss 0.0028772
# --------------------------------------------------------------------------------
# | end of epoch  25 | time:  9.82s
# --------------------------------------------------------------------------------
# | epoch  26 |     8/   82 batches | lr 0.0000131760 | 134.37 ms | loss 0.1055272
# | epoch  26 |    16/   82 batches | lr 0.0000131760 | 118.75 ms | loss 0.0120873
# | epoch  26 |    24/   82 batches | lr 0.0000131760 | 119.00 ms | loss 0.0353570
# | epoch  26 |    32/   82 batches | lr 0.0000131760 | 118.88 ms | loss 0.0115942
# | epoch  26 |    40/   82 batches | lr 0.0000131760 | 119.00 ms | loss 0.0035806
# | epoch  26 |    48/   82 batches | lr 0.0000131760 | 119.13 ms | loss 0.0033039
# | epoch  26 |    56/   82 batches | lr 0.0000131760 | 119.44 ms | loss 0.0031159
# | epoch  26 |    64/   82 batches | lr 0.0000131760 | 119.07 ms | loss 0.0027640
# | epoch  26 |    72/   82 batches | lr 0.0000131760 | 119.64 ms | loss 0.0027712
# | epoch  26 |    80/   82 batches | lr 0.0000131760 | 119.63 ms | loss 0.0028230
# --------------------------------------------------------------------------------
# | end of epoch  26 | time:  9.82s
# --------------------------------------------------------------------------------
# | epoch  27 |     8/   82 batches | lr 0.0000125172 | 135.19 ms | loss 0.0985938
# | epoch  27 |    16/   82 batches | lr 0.0000125172 | 119.18 ms | loss 0.0111138
# | epoch  27 |    24/   82 batches | lr 0.0000125172 | 119.99 ms | loss 0.0332069
# | epoch  27 |    32/   82 batches | lr 0.0000125172 | 119.13 ms | loss 0.0115773
# | epoch  27 |    40/   82 batches | lr 0.0000125172 | 120.47 ms | loss 0.0035530
# | epoch  27 |    48/   82 batches | lr 0.0000125172 | 119.00 ms | loss 0.0033101
# | epoch  27 |    56/   82 batches | lr 0.0000125172 | 119.12 ms | loss 0.0030236
# | epoch  27 |    64/   82 batches | lr 0.0000125172 | 119.09 ms | loss 0.0027312
# | epoch  27 |    72/   82 batches | lr 0.0000125172 | 119.25 ms | loss 0.0027460
# | epoch  27 |    80/   82 batches | lr 0.0000125172 | 119.00 ms | loss 0.0027800
# --------------------------------------------------------------------------------
# | end of epoch  27 | time:  9.84s
# --------------------------------------------------------------------------------
# | epoch  28 |     8/   82 batches | lr 0.0000118913 | 134.00 ms | loss 0.0920408
# | epoch  28 |    16/   82 batches | lr 0.0000118913 | 119.50 ms | loss 0.0101595
# | epoch  28 |    24/   82 batches | lr 0.0000118913 | 119.12 ms | loss 0.0311419
# | epoch  28 |    32/   82 batches | lr 0.0000118913 | 119.50 ms | loss 0.0115033
# | epoch  28 |    40/   82 batches | lr 0.0000118913 | 118.75 ms | loss 0.0034348
# | epoch  28 |    48/   82 batches | lr 0.0000118913 | 119.13 ms | loss 0.0033087
# | epoch  28 |    56/   82 batches | lr 0.0000118913 | 119.00 ms | loss 0.0029133
# | epoch  28 |    64/   82 batches | lr 0.0000118913 | 119.15 ms | loss 0.0026684
# | epoch  28 |    72/   82 batches | lr 0.0000118913 | 119.81 ms | loss 0.0026746
# | epoch  28 |    80/   82 batches | lr 0.0000118913 | 119.50 ms | loss 0.0027368
# --------------------------------------------------------------------------------
# | end of epoch  28 | time:  9.82s
# --------------------------------------------------------------------------------
# | epoch  29 |     8/   82 batches | lr 0.0000112968 | 134.13 ms | loss 0.0850736
# | epoch  29 |    16/   82 batches | lr 0.0000112968 | 119.25 ms | loss 0.0093734
# | epoch  29 |    24/   82 batches | lr 0.0000112968 | 119.12 ms | loss 0.0289279
# | epoch  29 |    32/   82 batches | lr 0.0000112968 | 120.63 ms | loss 0.0112399
# | epoch  29 |    40/   82 batches | lr 0.0000112968 | 123.25 ms | loss 0.0033712
# | epoch  29 |    48/   82 batches | lr 0.0000112968 | 120.88 ms | loss 0.0033281
# | epoch  29 |    56/   82 batches | lr 0.0000112968 | 123.00 ms | loss 0.0028936
# | epoch  29 |    64/   82 batches | lr 0.0000112968 | 121.28 ms | loss 0.0026173
# | epoch  29 |    72/   82 batches | lr 0.0000112968 | 118.75 ms | loss 0.0026260
# | epoch  29 |    80/   82 batches | lr 0.0000112968 | 120.13 ms | loss 0.0026927
# --------------------------------------------------------------------------------
# | end of epoch  29 | time:  9.93s
# --------------------------------------------------------------------------------
# | epoch  30 |     8/   82 batches | lr 0.0000107319 | 134.25 ms | loss 0.0791818
# | epoch  30 |    16/   82 batches | lr 0.0000107319 | 120.75 ms | loss 0.0087249
# | epoch  30 |    24/   82 batches | lr 0.0000107319 | 119.25 ms | loss 0.0272910
# | epoch  30 |    32/   82 batches | lr 0.0000107319 | 119.75 ms | loss 0.0108799
# | epoch  30 |    40/   82 batches | lr 0.0000107319 | 119.00 ms | loss 0.0033420
# | epoch  30 |    48/   82 batches | lr 0.0000107319 | 119.25 ms | loss 0.0033186
# | epoch  30 |    56/   82 batches | lr 0.0000107319 | 119.50 ms | loss 0.0028097
# | epoch  30 |    64/   82 batches | lr 0.0000107319 | 119.25 ms | loss 0.0026099
# | epoch  30 |    72/   82 batches | lr 0.0000107319 | 119.37 ms | loss 0.0025896
# | epoch  30 |    80/   82 batches | lr 0.0000107319 | 119.31 ms | loss 0.0026713
# --------------------------------------------------------------------------------
# | end of epoch  30 | time:  9.84s
# --------------------------------------------------------------------------------
# | epoch  31 |     8/   82 batches | lr 0.0000101953 | 133.87 ms | loss 0.0732247
# | epoch  31 |    16/   82 batches | lr 0.0000101953 | 119.37 ms | loss 0.0080727
# | epoch  31 |    24/   82 batches | lr 0.0000101953 | 119.64 ms | loss 0.0253303
# | epoch  31 |    32/   82 batches | lr 0.0000101953 | 119.00 ms | loss 0.0105468
# | epoch  31 |    40/   82 batches | lr 0.0000101953 | 119.00 ms | loss 0.0032844
# | epoch  31 |    48/   82 batches | lr 0.0000101953 | 119.13 ms | loss 0.0033467
# | epoch  31 |    56/   82 batches | lr 0.0000101953 | 119.25 ms | loss 0.0027589
# | epoch  31 |    64/   82 batches | lr 0.0000101953 | 119.27 ms | loss 0.0025644
# | epoch  31 |    72/   82 batches | lr 0.0000101953 | 119.50 ms | loss 0.0025602
# | epoch  31 |    80/   82 batches | lr 0.0000101953 | 119.37 ms | loss 0.0026252
# --------------------------------------------------------------------------------
# | end of epoch  31 | time:  9.82s
# --------------------------------------------------------------------------------
# | epoch  32 |     8/   82 batches | lr 0.0000096856 | 134.25 ms | loss 0.0670856
# | epoch  32 |    16/   82 batches | lr 0.0000096856 | 120.12 ms | loss 0.0076390
# | epoch  32 |    24/   82 batches | lr 0.0000096856 | 118.88 ms | loss 0.0235866
# | epoch  32 |    32/   82 batches | lr 0.0000096856 | 120.13 ms | loss 0.0098342
# | epoch  32 |    40/   82 batches | lr 0.0000096856 | 119.12 ms | loss 0.0032360
# | epoch  32 |    48/   82 batches | lr 0.0000096856 | 119.63 ms | loss 0.0032408
# | epoch  32 |    56/   82 batches | lr 0.0000096856 | 119.00 ms | loss 0.0027102
# | epoch  32 |    64/   82 batches | lr 0.0000096856 | 120.00 ms | loss 0.0024927
# | epoch  32 |    72/   82 batches | lr 0.0000096856 | 119.00 ms | loss 0.0025120
# | epoch  32 |    80/   82 batches | lr 0.0000096856 | 118.82 ms | loss 0.0026181
# --------------------------------------------------------------------------------
# | end of epoch  32 | time:  9.83s
# --------------------------------------------------------------------------------
# | epoch  33 |     8/   82 batches | lr 0.0000092013 | 134.50 ms | loss 0.0613726
# | epoch  33 |    16/   82 batches | lr 0.0000092013 | 119.63 ms | loss 0.0071385
# | epoch  33 |    24/   82 batches | lr 0.0000092013 | 120.00 ms | loss 0.0217710
# | epoch  33 |    32/   82 batches | lr 0.0000092013 | 119.88 ms | loss 0.0092528
# | epoch  33 |    40/   82 batches | lr 0.0000092013 | 119.25 ms | loss 0.0032355
# | epoch  33 |    48/   82 batches | lr 0.0000092013 | 120.37 ms | loss 0.0032418
# | epoch  33 |    56/   82 batches | lr 0.0000092013 | 119.25 ms | loss 0.0026689
# | epoch  33 |    64/   82 batches | lr 0.0000092013 | 120.13 ms | loss 0.0024788
# | epoch  33 |    72/   82 batches | lr 0.0000092013 | 118.88 ms | loss 0.0024637
# | epoch  33 |    80/   82 batches | lr 0.0000092013 | 119.75 ms | loss 0.0025572
# --------------------------------------------------------------------------------
# | end of epoch  33 | time:  9.86s
# --------------------------------------------------------------------------------
# | epoch  34 |     8/   82 batches | lr 0.0000087412 | 133.75 ms | loss 0.0552933
# | epoch  34 |    16/   82 batches | lr 0.0000087412 | 120.50 ms | loss 0.0067240
# | epoch  34 |    24/   82 batches | lr 0.0000087412 | 119.74 ms | loss 0.0201277
# | epoch  34 |    32/   82 batches | lr 0.0000087412 | 120.00 ms | loss 0.0085517
# | epoch  34 |    40/   82 batches | lr 0.0000087412 | 120.37 ms | loss 0.0032382
# | epoch  34 |    48/   82 batches | lr 0.0000087412 | 120.93 ms | loss 0.0030980
# | epoch  34 |    56/   82 batches | lr 0.0000087412 | 120.13 ms | loss 0.0026007
# | epoch  34 |    64/   82 batches | lr 0.0000087412 | 120.05 ms | loss 0.0024016
# | epoch  34 |    72/   82 batches | lr 0.0000087412 | 119.91 ms | loss 0.0024314
# | epoch  34 |    80/   82 batches | lr 0.0000087412 | 120.25 ms | loss 0.0025344
# --------------------------------------------------------------------------------
# | end of epoch  34 | time:  9.89s
# --------------------------------------------------------------------------------
# | epoch  35 |     8/   82 batches | lr 0.0000083042 | 134.63 ms | loss 0.0502196
# | epoch  35 |    16/   82 batches | lr 0.0000083042 | 120.25 ms | loss 0.0064048
# | epoch  35 |    24/   82 batches | lr 0.0000083042 | 120.13 ms | loss 0.0183941
# | epoch  35 |    32/   82 batches | lr 0.0000083042 | 120.25 ms | loss 0.0077503
# | epoch  35 |    40/   82 batches | lr 0.0000083042 | 119.88 ms | loss 0.0032063
# | epoch  35 |    48/   82 batches | lr 0.0000083042 | 119.88 ms | loss 0.0031155
# | epoch  35 |    56/   82 batches | lr 0.0000083042 | 118.87 ms | loss 0.0025935
# | epoch  35 |    64/   82 batches | lr 0.0000083042 | 118.88 ms | loss 0.0023692
# | epoch  35 |    72/   82 batches | lr 0.0000083042 | 118.62 ms | loss 0.0023931
# | epoch  35 |    80/   82 batches | lr 0.0000083042 | 119.25 ms | loss 0.0024994
# --------------------------------------------------------------------------------
# | end of epoch  35 | time:  9.85s
# --------------------------------------------------------------------------------
# | epoch  36 |     8/   82 batches | lr 0.0000078890 | 133.75 ms | loss 0.0444853
# | epoch  36 |    16/   82 batches | lr 0.0000078890 | 119.26 ms | loss 0.0059757
# | epoch  36 |    24/   82 batches | lr 0.0000078890 | 118.65 ms | loss 0.0168391
# | epoch  36 |    32/   82 batches | lr 0.0000078890 | 119.04 ms | loss 0.0070398
# | epoch  36 |    40/   82 batches | lr 0.0000078890 | 118.50 ms | loss 0.0031896
# | epoch  36 |    48/   82 batches | lr 0.0000078890 | 119.00 ms | loss 0.0029764
# | epoch  36 |    56/   82 batches | lr 0.0000078890 | 119.25 ms | loss 0.0025431
# | epoch  36 |    64/   82 batches | lr 0.0000078890 | 119.00 ms | loss 0.0023160
# | epoch  36 |    72/   82 batches | lr 0.0000078890 | 119.37 ms | loss 0.0023664
# | epoch  36 |    80/   82 batches | lr 0.0000078890 | 118.75 ms | loss 0.0024612
# --------------------------------------------------------------------------------
# | end of epoch  36 | time:  9.80s
# --------------------------------------------------------------------------------
# | epoch  37 |     8/   82 batches | lr 0.0000074945 | 133.50 ms | loss 0.0401082
# | epoch  37 |    16/   82 batches | lr 0.0000074945 | 119.12 ms | loss 0.0057072
# | epoch  37 |    24/   82 batches | lr 0.0000074945 | 118.75 ms | loss 0.0155810
# | epoch  37 |    32/   82 batches | lr 0.0000074945 | 118.90 ms | loss 0.0063927
# | epoch  37 |    40/   82 batches | lr 0.0000074945 | 118.62 ms | loss 0.0032044
# | epoch  37 |    48/   82 batches | lr 0.0000074945 | 119.16 ms | loss 0.0028799
# | epoch  37 |    56/   82 batches | lr 0.0000074945 | 118.84 ms | loss 0.0024706
# | epoch  37 |    64/   82 batches | lr 0.0000074945 | 118.76 ms | loss 0.0022832
# | epoch  37 |    72/   82 batches | lr 0.0000074945 | 119.38 ms | loss 0.0023355
# | epoch  37 |    80/   82 batches | lr 0.0000074945 | 118.50 ms | loss 0.0024337
# --------------------------------------------------------------------------------
# | end of epoch  37 | time:  9.79s
# --------------------------------------------------------------------------------
# | epoch  38 |     8/   82 batches | lr 0.0000071198 | 134.00 ms | loss 0.0362894
# | epoch  38 |    16/   82 batches | lr 0.0000071198 | 118.62 ms | loss 0.0054867
# | epoch  38 |    24/   82 batches | lr 0.0000071198 | 119.26 ms | loss 0.0143124
# | epoch  38 |    32/   82 batches | lr 0.0000071198 | 118.75 ms | loss 0.0057938
# | epoch  38 |    40/   82 batches | lr 0.0000071198 | 119.13 ms | loss 0.0032153
# | epoch  38 |    48/   82 batches | lr 0.0000071198 | 119.13 ms | loss 0.0027607
# | epoch  38 |    56/   82 batches | lr 0.0000071198 | 119.35 ms | loss 0.0024485
# | epoch  38 |    64/   82 batches | lr 0.0000071198 | 119.13 ms | loss 0.0022589
# | epoch  38 |    72/   82 batches | lr 0.0000071198 | 119.25 ms | loss 0.0023000
# | epoch  38 |    80/   82 batches | lr 0.0000071198 | 119.38 ms | loss 0.0024262
# --------------------------------------------------------------------------------
# | end of epoch  38 | time:  9.81s
# --------------------------------------------------------------------------------
# | epoch  39 |     8/   82 batches | lr 0.0000067638 | 134.12 ms | loss 0.0323418
# | epoch  39 |    16/   82 batches | lr 0.0000067638 | 119.04 ms | loss 0.0052096
# | epoch  39 |    24/   82 batches | lr 0.0000067638 | 118.75 ms | loss 0.0130604
# | epoch  39 |    32/   82 batches | lr 0.0000067638 | 119.12 ms | loss 0.0052339
# | epoch  39 |    40/   82 batches | lr 0.0000067638 | 119.00 ms | loss 0.0031838
# | epoch  39 |    48/   82 batches | lr 0.0000067638 | 119.00 ms | loss 0.0026855
# | epoch  39 |    56/   82 batches | lr 0.0000067638 | 118.88 ms | loss 0.0024013
# | epoch  39 |    64/   82 batches | lr 0.0000067638 | 119.32 ms | loss 0.0022280
# | epoch  39 |    72/   82 batches | lr 0.0000067638 | 118.87 ms | loss 0.0022733
# | epoch  39 |    80/   82 batches | lr 0.0000067638 | 119.00 ms | loss 0.0023729
# --------------------------------------------------------------------------------
# | end of epoch  39 | time:  9.81s
# --------------------------------------------------------------------------------
# | epoch  40 |     8/   82 batches | lr 0.0000064256 | 133.75 ms | loss 0.0285664
# | epoch  40 |    16/   82 batches | lr 0.0000064256 | 119.00 ms | loss 0.0050001
# | epoch  40 |    24/   82 batches | lr 0.0000064256 | 118.75 ms | loss 0.0118063
# | epoch  40 |    32/   82 batches | lr 0.0000064256 | 119.13 ms | loss 0.0047187
# | epoch  40 |    40/   82 batches | lr 0.0000064256 | 118.88 ms | loss 0.0031106
# | epoch  40 |    48/   82 batches | lr 0.0000064256 | 119.06 ms | loss 0.0026009
# | epoch  40 |    56/   82 batches | lr 0.0000064256 | 118.63 ms | loss 0.0023462
# | epoch  40 |    64/   82 batches | lr 0.0000064256 | 118.87 ms | loss 0.0021681
# | epoch  40 |    72/   82 batches | lr 0.0000064256 | 118.75 ms | loss 0.0022231
# | epoch  40 |    80/   82 batches | lr 0.0000064256 | 118.75 ms | loss 0.0023834
# --------------------------------------------------------------------------------
# | end of epoch  40 | time:  9.79s
# --------------------------------------------------------------------------------
# | epoch  41 |     8/   82 batches | lr 0.0000061043 | 133.50 ms | loss 0.0255158
# | epoch  41 |    16/   82 batches | lr 0.0000061043 | 119.00 ms | loss 0.0048142
# | epoch  41 |    24/   82 batches | lr 0.0000061043 | 118.87 ms | loss 0.0108163
# | epoch  41 |    32/   82 batches | lr 0.0000061043 | 120.00 ms | loss 0.0043546
# | epoch  41 |    40/   82 batches | lr 0.0000061043 | 118.88 ms | loss 0.0030708
# | epoch  41 |    48/   82 batches | lr 0.0000061043 | 119.25 ms | loss 0.0025726
# | epoch  41 |    56/   82 batches | lr 0.0000061043 | 118.62 ms | loss 0.0023135
# | epoch  41 |    64/   82 batches | lr 0.0000061043 | 119.50 ms | loss 0.0021734
# | epoch  41 |    72/   82 batches | lr 0.0000061043 | 118.63 ms | loss 0.0021955
# | epoch  41 |    80/   82 batches | lr 0.0000061043 | 118.75 ms | loss 0.0023315
# --------------------------------------------------------------------------------
# | end of epoch  41 | time:  9.80s
# --------------------------------------------------------------------------------
# | epoch  42 |     8/   82 batches | lr 0.0000057991 | 133.75 ms | loss 0.0230346
# | epoch  42 |    16/   82 batches | lr 0.0000057991 | 118.88 ms | loss 0.0046248
# | epoch  42 |    24/   82 batches | lr 0.0000057991 | 119.12 ms | loss 0.0100171
# | epoch  42 |    32/   82 batches | lr 0.0000057991 | 118.50 ms | loss 0.0039869
# | epoch  42 |    40/   82 batches | lr 0.0000057991 | 119.19 ms | loss 0.0030646
# | epoch  42 |    48/   82 batches | lr 0.0000057991 | 118.62 ms | loss 0.0025022
# | epoch  42 |    56/   82 batches | lr 0.0000057991 | 119.25 ms | loss 0.0022506
# | epoch  42 |    64/   82 batches | lr 0.0000057991 | 118.63 ms | loss 0.0021478
# | epoch  42 |    72/   82 batches | lr 0.0000057991 | 119.26 ms | loss 0.0021744
# | epoch  42 |    80/   82 batches | lr 0.0000057991 | 118.87 ms | loss 0.0023286
# --------------------------------------------------------------------------------
# | end of epoch  42 | time:  9.79s
# --------------------------------------------------------------------------------
# | epoch  43 |     8/   82 batches | lr 0.0000055092 | 133.88 ms | loss 0.0206085
# | epoch  43 |    16/   82 batches | lr 0.0000055092 | 119.13 ms | loss 0.0044616
# | epoch  43 |    24/   82 batches | lr 0.0000055092 | 118.75 ms | loss 0.0091686
# | epoch  43 |    32/   82 batches | lr 0.0000055092 | 118.88 ms | loss 0.0036694
# | epoch  43 |    40/   82 batches | lr 0.0000055092 | 118.75 ms | loss 0.0029617
# | epoch  43 |    48/   82 batches | lr 0.0000055092 | 119.50 ms | loss 0.0024259
# | epoch  43 |    56/   82 batches | lr 0.0000055092 | 118.75 ms | loss 0.0022525
# | epoch  43 |    64/   82 batches | lr 0.0000055092 | 119.12 ms | loss 0.0020879
# | epoch  43 |    72/   82 batches | lr 0.0000055092 | 119.13 ms | loss 0.0021494
# | epoch  43 |    80/   82 batches | lr 0.0000055092 | 118.63 ms | loss 0.0023000
# --------------------------------------------------------------------------------
# | end of epoch  43 | time:  9.80s
# --------------------------------------------------------------------------------
# | epoch  44 |     8/   82 batches | lr 0.0000052337 | 134.00 ms | loss 0.0186251
# | epoch  44 |    16/   82 batches | lr 0.0000052337 | 119.00 ms | loss 0.0042947
# | epoch  44 |    24/   82 batches | lr 0.0000052337 | 119.25 ms | loss 0.0083911
# | epoch  44 |    32/   82 batches | lr 0.0000052337 | 118.75 ms | loss 0.0034793
# | epoch  44 |    40/   82 batches | lr 0.0000052337 | 119.25 ms | loss 0.0029271
# | epoch  44 |    48/   82 batches | lr 0.0000052337 | 118.81 ms | loss 0.0023881
# | epoch  44 |    56/   82 batches | lr 0.0000052337 | 118.62 ms | loss 0.0021764
# | epoch  44 |    64/   82 batches | lr 0.0000052337 | 119.12 ms | loss 0.0020743
# | epoch  44 |    72/   82 batches | lr 0.0000052337 | 118.75 ms | loss 0.0021166
# | epoch  44 |    80/   82 batches | lr 0.0000052337 | 119.25 ms | loss 0.0022705
# --------------------------------------------------------------------------------
# | end of epoch  44 | time:  9.80s
# --------------------------------------------------------------------------------
# | epoch  45 |     8/   82 batches | lr 0.0000049720 | 133.94 ms | loss 0.0170980
# | epoch  45 |    16/   82 batches | lr 0.0000049720 | 119.50 ms | loss 0.0042246
# | epoch  45 |    24/   82 batches | lr 0.0000049720 | 119.02 ms | loss 0.0078151
# | epoch  45 |    32/   82 batches | lr 0.0000049720 | 119.03 ms | loss 0.0032885
# | epoch  45 |    40/   82 batches | lr 0.0000049720 | 118.50 ms | loss 0.0028578
# | epoch  45 |    48/   82 batches | lr 0.0000049720 | 120.08 ms | loss 0.0023556
# | epoch  45 |    56/   82 batches | lr 0.0000049720 | 118.88 ms | loss 0.0021477
# | epoch  45 |    64/   82 batches | lr 0.0000049720 | 119.13 ms | loss 0.0020677
# | epoch  45 |    72/   82 batches | lr 0.0000049720 | 118.87 ms | loss 0.0021028
# | epoch  45 |    80/   82 batches | lr 0.0000049720 | 119.32 ms | loss 0.0022369
# --------------------------------------------------------------------------------
# | end of epoch  45 | time:  9.81s
# --------------------------------------------------------------------------------
# | epoch  46 |     8/   82 batches | lr 0.0000047234 | 133.51 ms | loss 0.0154695
# | epoch  46 |    16/   82 batches | lr 0.0000047234 | 119.25 ms | loss 0.0040575
# | epoch  46 |    24/   82 batches | lr 0.0000047234 | 118.62 ms | loss 0.0073294
# | epoch  46 |    32/   82 batches | lr 0.0000047234 | 119.00 ms | loss 0.0031368
# | epoch  46 |    40/   82 batches | lr 0.0000047234 | 119.13 ms | loss 0.0028020
# | epoch  46 |    48/   82 batches | lr 0.0000047234 | 122.12 ms | loss 0.0023176
# | epoch  46 |    56/   82 batches | lr 0.0000047234 | 119.63 ms | loss 0.0021100
# | epoch  46 |    64/   82 batches | lr 0.0000047234 | 120.38 ms | loss 0.0020465
# | epoch  46 |    72/   82 batches | lr 0.0000047234 | 119.25 ms | loss 0.0020760
# | epoch  46 |    80/   82 batches | lr 0.0000047234 | 119.13 ms | loss 0.0022390
# --------------------------------------------------------------------------------
# | end of epoch  46 | time:  9.84s
# --------------------------------------------------------------------------------
# | epoch  47 |     8/   82 batches | lr 0.0000044872 | 133.50 ms | loss 0.0141631
# | epoch  47 |    16/   82 batches | lr 0.0000044872 | 118.62 ms | loss 0.0039231
# | epoch  47 |    24/   82 batches | lr 0.0000044872 | 119.35 ms | loss 0.0068323
# | epoch  47 |    32/   82 batches | lr 0.0000044872 | 118.76 ms | loss 0.0029964
# | epoch  47 |    40/   82 batches | lr 0.0000044872 | 119.18 ms | loss 0.0027457
# | epoch  47 |    48/   82 batches | lr 0.0000044872 | 119.00 ms | loss 0.0022539
# | epoch  47 |    56/   82 batches | lr 0.0000044872 | 119.12 ms | loss 0.0020895
# | epoch  47 |    64/   82 batches | lr 0.0000044872 | 118.75 ms | loss 0.0020218
# | epoch  47 |    72/   82 batches | lr 0.0000044872 | 119.00 ms | loss 0.0020474
# | epoch  47 |    80/   82 batches | lr 0.0000044872 | 118.87 ms | loss 0.0021944
# --------------------------------------------------------------------------------
# | end of epoch  47 | time:  9.80s
# --------------------------------------------------------------------------------
# | epoch  48 |     8/   82 batches | lr 0.0000042629 | 133.50 ms | loss 0.0129866
# | epoch  48 |    16/   82 batches | lr 0.0000042629 | 119.75 ms | loss 0.0038129
# | epoch  48 |    24/   82 batches | lr 0.0000042629 | 118.50 ms | loss 0.0064202
# | epoch  48 |    32/   82 batches | lr 0.0000042629 | 119.25 ms | loss 0.0028881
# | epoch  48 |    40/   82 batches | lr 0.0000042629 | 118.88 ms | loss 0.0026922
# ...
# | epoch  85 |    24/   82 batches | lr 0.0000006390 | 133.99 ms | loss 0.0026674
# | epoch  85 |    32/   82 batches | lr 0.0000006390 | 135.35 ms | loss 0.0022424
# | epoch  85 |    40/   82 batches | lr 0.0000006390 | 133.40 ms | loss 0.0017678
# | epoch  85 |    48/   82 batches | lr 0.0000006390 | 132.74 ms | loss 0.0017462
# | epoch  85 |    56/   82 batches | lr 0.0000006390 | 132.48 ms | loss 0.0017612
# | epoch  85 |    64/   82 batches | lr 0.0000006390 | 132.58 ms | loss 0.0016490
# | epoch  85 |    72/   82 batches | lr 0.0000006390 | 133.07 ms | loss 0.0016780
# | epoch  85 |    80/   82 batches | lr 0.0000006390 | 132.73 ms | loss 0.0018756
# --------------------------------------------------------------------------------
# | end of epoch  85 | time: 10.92s
# --------------------------------------------------------------------------------
# | epoch  86 |     8/   82 batches | lr 0.0000006070 | 148.38 ms | loss 0.0044351
# | epoch  86 |    16/   82 batches | lr 0.0000006070 | 132.93 ms | loss 0.0023311
# | epoch  86 |    24/   82 batches | lr 0.0000006070 | 132.08 ms | loss 0.0026574
# | epoch  86 |    32/   82 batches | lr 0.0000006070 | 132.85 ms | loss 0.0022421
# | epoch  86 |    40/   82 batches | lr 0.0000006070 | 131.46 ms | loss 0.0017303
# | epoch  86 |    48/   82 batches | lr 0.0000006070 | 132.49 ms | loss 0.0017131
# | epoch  86 |    56/   82 batches | lr 0.0000006070 | 131.67 ms | loss 0.0017521
# | epoch  86 |    64/   82 batches | lr 0.0000006070 | 132.02 ms | loss 0.0016562
# | epoch  86 |    72/   82 batches | lr 0.0000006070 | 131.61 ms | loss 0.0016921
# | epoch  86 |    80/   82 batches | lr 0.0000006070 | 132.14 ms | loss 0.0018978
# --------------------------------------------------------------------------------
# | end of epoch  86 | time: 10.88s
# --------------------------------------------------------------------------------
# | epoch  87 |     8/   82 batches | lr 0.0000005767 | 148.48 ms | loss 0.0044769
# | epoch  87 |    16/   82 batches | lr 0.0000005767 | 133.80 ms | loss 0.0022865
# | epoch  87 |    24/   82 batches | lr 0.0000005767 | 131.87 ms | loss 0.0026121
# | epoch  87 |    32/   82 batches | lr 0.0000005767 | 134.98 ms | loss 0.0022586
# | epoch  87 |    40/   82 batches | lr 0.0000005767 | 133.11 ms | loss 0.0017483
# | epoch  87 |    48/   82 batches | lr 0.0000005767 | 132.49 ms | loss 0.0016960
# | epoch  87 |    56/   82 batches | lr 0.0000005767 | 132.74 ms | loss 0.0017577
# | epoch  87 |    64/   82 batches | lr 0.0000005767 | 133.67 ms | loss 0.0016555
# | epoch  87 |    72/   82 batches | lr 0.0000005767 | 128.02 ms | loss 0.0016879
# | epoch  87 |    80/   82 batches | lr 0.0000005767 | 123.50 ms | loss 0.0018843
# --------------------------------------------------------------------------------
# | end of epoch  87 | time: 10.83s
# --------------------------------------------------------------------------------
# | epoch  88 |     8/   82 batches | lr 0.0000005478 | 139.50 ms | loss 0.0043993
# | epoch  88 |    16/   82 batches | lr 0.0000005478 | 122.63 ms | loss 0.0022668
# | epoch  88 |    24/   82 batches | lr 0.0000005478 | 122.87 ms | loss 0.0025941
# | epoch  88 |    32/   82 batches | lr 0.0000005478 | 123.13 ms | loss 0.0022369
# | epoch  88 |    40/   82 batches | lr 0.0000005478 | 123.00 ms | loss 0.0017575
# | epoch  88 |    48/   82 batches | lr 0.0000005478 | 123.13 ms | loss 0.0016727
# | epoch  88 |    56/   82 batches | lr 0.0000005478 | 122.87 ms | loss 0.0017119
# | epoch  88 |    64/   82 batches | lr 0.0000005478 | 124.00 ms | loss 0.0016469
# | epoch  88 |    72/   82 batches | lr 0.0000005478 | 123.75 ms | loss 0.0016754
# | epoch  88 |    80/   82 batches | lr 0.0000005478 | 123.19 ms | loss 0.0018876
# --------------------------------------------------------------------------------
# | end of epoch  88 | time: 10.15s
# --------------------------------------------------------------------------------
# | epoch  89 |     8/   82 batches | lr 0.0000005204 | 138.85 ms | loss 0.0043865
# | epoch  89 |    16/   82 batches | lr 0.0000005204 | 122.76 ms | loss 0.0022525
# | epoch  89 |    24/   82 batches | lr 0.0000005204 | 121.75 ms | loss 0.0025447
# | epoch  89 |    32/   82 batches | lr 0.0000005204 | 122.25 ms | loss 0.0022613
# | epoch  89 |    40/   82 batches | lr 0.0000005204 | 122.13 ms | loss 0.0017754
# | epoch  89 |    48/   82 batches | lr 0.0000005204 | 122.38 ms | loss 0.0016618
# | epoch  89 |    56/   82 batches | lr 0.0000005204 | 122.12 ms | loss 0.0017331
# | epoch  89 |    64/   82 batches | lr 0.0000005204 | 122.29 ms | loss 0.0016726
# | epoch  89 |    72/   82 batches | lr 0.0000005204 | 122.12 ms | loss 0.0016625
# | epoch  89 |    80/   82 batches | lr 0.0000005204 | 122.50 ms | loss 0.0018849
# --------------------------------------------------------------------------------
# | end of epoch  89 | time: 10.08s
# --------------------------------------------------------------------------------
# | epoch  90 |     8/   82 batches | lr 0.0000004944 | 137.25 ms | loss 0.0044017
# | epoch  90 |    16/   82 batches | lr 0.0000004944 | 122.50 ms | loss 0.0022935
# | epoch  90 |    24/   82 batches | lr 0.0000004944 | 121.87 ms | loss 0.0025510
# | epoch  90 |    32/   82 batches | lr 0.0000004944 | 122.25 ms | loss 0.0022639
# | epoch  90 |    40/   82 batches | lr 0.0000004944 | 122.25 ms | loss 0.0017631
# | epoch  90 |    48/   82 batches | lr 0.0000004944 | 122.25 ms | loss 0.0016753
# | epoch  90 |    56/   82 batches | lr 0.0000004944 | 122.13 ms | loss 0.0017155
# | epoch  90 |    64/   82 batches | lr 0.0000004944 | 122.38 ms | loss 0.0016853
# | epoch  90 |    72/   82 batches | lr 0.0000004944 | 122.12 ms | loss 0.0016585
# | epoch  90 |    80/   82 batches | lr 0.0000004944 | 122.38 ms | loss 0.0018726
# --------------------------------------------------------------------------------
# | end of epoch  90 | time: 10.07s
# --------------------------------------------------------------------------------
# | epoch  91 |     8/   82 batches | lr 0.0000004697 | 137.50 ms | loss 0.0044824
# | epoch  91 |    16/   82 batches | lr 0.0000004697 | 122.38 ms | loss 0.0022564
# | epoch  91 |    24/   82 batches | lr 0.0000004697 | 122.13 ms | loss 0.0025424
# | epoch  91 |    32/   82 batches | lr 0.0000004697 | 122.31 ms | loss 0.0022451
# | epoch  91 |    40/   82 batches | lr 0.0000004697 | 122.19 ms | loss 0.0017654
# | epoch  91 |    48/   82 batches | lr 0.0000004697 | 122.38 ms | loss 0.0016292
# | epoch  91 |    56/   82 batches | lr 0.0000004697 | 122.00 ms | loss 0.0016724
# | epoch  91 |    64/   82 batches | lr 0.0000004697 | 122.00 ms | loss 0.0017023
# | epoch  91 |    72/   82 batches | lr 0.0000004697 | 122.20 ms | loss 0.0016765
# | epoch  91 |    80/   82 batches | lr 0.0000004697 | 122.25 ms | loss 0.0018629
# --------------------------------------------------------------------------------
# | end of epoch  91 | time: 10.07s
# --------------------------------------------------------------------------------
# | epoch  92 |     8/   82 batches | lr 0.0000004462 | 137.00 ms | loss 0.0043894
# | epoch  92 |    16/   82 batches | lr 0.0000004462 | 122.13 ms | loss 0.0022578
# | epoch  92 |    24/   82 batches | lr 0.0000004462 | 122.13 ms | loss 0.0024472
# | epoch  92 |    32/   82 batches | lr 0.0000004462 | 122.25 ms | loss 0.0022315
# | epoch  92 |    40/   82 batches | lr 0.0000004462 | 122.00 ms | loss 0.0017671
# | epoch  92 |    48/   82 batches | lr 0.0000004462 | 121.50 ms | loss 0.0016088
# | epoch  92 |    56/   82 batches | lr 0.0000004462 | 119.88 ms | loss 0.0016788
# | epoch  92 |    64/   82 batches | lr 0.0000004462 | 119.75 ms | loss 0.0016805
# | epoch  92 |    72/   82 batches | lr 0.0000004462 | 120.12 ms | loss 0.0016662
# | epoch  92 |    80/   82 batches | lr 0.0000004462 | 119.87 ms | loss 0.0018513
# --------------------------------------------------------------------------------
# | end of epoch  92 | time:  9.98s
# --------------------------------------------------------------------------------
# | epoch  93 |     8/   82 batches | lr 0.0000004239 | 137.12 ms | loss 0.0042892
# | epoch  93 |    16/   82 batches | lr 0.0000004239 | 121.88 ms | loss 0.0022778
# | epoch  93 |    24/   82 batches | lr 0.0000004239 | 122.25 ms | loss 0.0024192
# | epoch  93 |    32/   82 batches | lr 0.0000004239 | 122.25 ms | loss 0.0022253
# | epoch  93 |    40/   82 batches | lr 0.0000004239 | 122.00 ms | loss 0.0017653
# | epoch  93 |    48/   82 batches | lr 0.0000004239 | 122.25 ms | loss 0.0016307
# | epoch  93 |    56/   82 batches | lr 0.0000004239 | 122.25 ms | loss 0.0016658
# | epoch  93 |    64/   82 batches | lr 0.0000004239 | 122.00 ms | loss 0.0016567
# | epoch  93 |    72/   82 batches | lr 0.0000004239 | 122.50 ms | loss 0.0016554
# | epoch  93 |    80/   82 batches | lr 0.0000004239 | 122.00 ms | loss 0.0018523
# --------------------------------------------------------------------------------
# | end of epoch  93 | time: 10.06s
# --------------------------------------------------------------------------------
# | epoch  94 |     8/   82 batches | lr 0.0000004027 | 137.68 ms | loss 0.0043297
# | epoch  94 |    16/   82 batches | lr 0.0000004027 | 122.25 ms | loss 0.0022498
# | epoch  94 |    24/   82 batches | lr 0.0000004027 | 121.91 ms | loss 0.0024143
# | epoch  94 |    32/   82 batches | lr 0.0000004027 | 124.13 ms | loss 0.0022298
# | epoch  94 |    40/   82 batches | lr 0.0000004027 | 123.60 ms | loss 0.0017624
# | epoch  94 |    48/   82 batches | lr 0.0000004027 | 123.76 ms | loss 0.0016201
# | epoch  94 |    56/   82 batches | lr 0.0000004027 | 122.88 ms | loss 0.0016555
# | epoch  94 |    64/   82 batches | lr 0.0000004027 | 122.77 ms | loss 0.0016602
# | epoch  94 |    72/   82 batches | lr 0.0000004027 | 124.26 ms | loss 0.0016564
# | epoch  94 |    80/   82 batches | lr 0.0000004027 | 123.42 ms | loss 0.0018438
# --------------------------------------------------------------------------------
# | end of epoch  94 | time: 10.14s
# --------------------------------------------------------------------------------
# | epoch  95 |     8/   82 batches | lr 0.0000003826 | 137.51 ms | loss 0.0043089
# | epoch  95 |    16/   82 batches | lr 0.0000003826 | 123.04 ms | loss 0.0022557
# | epoch  95 |    24/   82 batches | lr 0.0000003826 | 122.13 ms | loss 0.0023818
# | epoch  95 |    32/   82 batches | lr 0.0000003826 | 123.64 ms | loss 0.0022278
# | epoch  95 |    40/   82 batches | lr 0.0000003826 | 123.22 ms | loss 0.0017833
# | epoch  95 |    48/   82 batches | lr 0.0000003826 | 123.40 ms | loss 0.0016045
# | epoch  95 |    56/   82 batches | lr 0.0000003826 | 124.40 ms | loss 0.0016413
# | epoch  95 |    64/   82 batches | lr 0.0000003826 | 124.23 ms | loss 0.0016813
# | epoch  95 |    72/   82 batches | lr 0.0000003826 | 124.32 ms | loss 0.0016543
# | epoch  95 |    80/   82 batches | lr 0.0000003826 | 124.55 ms | loss 0.0018419
# --------------------------------------------------------------------------------
# | end of epoch  95 | time: 10.17s
# --------------------------------------------------------------------------------
# | epoch  96 |     8/   82 batches | lr 0.0000003634 | 138.74 ms | loss 0.0042706
# | epoch  96 |    16/   82 batches | lr 0.0000003634 | 123.26 ms | loss 0.0022389
# | epoch  96 |    24/   82 batches | lr 0.0000003634 | 123.20 ms | loss 0.0023299
# | epoch  96 |    32/   82 batches | lr 0.0000003634 | 123.09 ms | loss 0.0022028
# | epoch  96 |    40/   82 batches | lr 0.0000003634 | 122.13 ms | loss 0.0017805
# | epoch  96 |    48/   82 batches | lr 0.0000003634 | 123.73 ms | loss 0.0015879
# | epoch  96 |    56/   82 batches | lr 0.0000003634 | 124.60 ms | loss 0.0016280
# | epoch  96 |    64/   82 batches | lr 0.0000003634 | 123.46 ms | loss 0.0016702
# | epoch  96 |    72/   82 batches | lr 0.0000003634 | 123.79 ms | loss 0.0016459
# | epoch  96 |    80/   82 batches | lr 0.0000003634 | 125.25 ms | loss 0.0018480
# --------------------------------------------------------------------------------
# | end of epoch  96 | time: 10.18s
# --------------------------------------------------------------------------------
# | epoch  97 |     8/   82 batches | lr 0.0000003453 | 139.00 ms | loss 0.0042337
# | epoch  97 |    16/   82 batches | lr 0.0000003453 | 124.02 ms | loss 0.0022547
# | epoch  97 |    24/   82 batches | lr 0.0000003453 | 124.64 ms | loss 0.0023309
# | epoch  97 |    32/   82 batches | lr 0.0000003453 | 124.26 ms | loss 0.0021943
# | epoch  97 |    40/   82 batches | lr 0.0000003453 | 122.25 ms | loss 0.0017778
# | epoch  97 |    48/   82 batches | lr 0.0000003453 | 124.13 ms | loss 0.0015777
# | epoch  97 |    56/   82 batches | lr 0.0000003453 | 122.14 ms | loss 0.0016504
# | epoch  97 |    64/   82 batches | lr 0.0000003453 | 122.56 ms | loss 0.0016649
# | epoch  97 |    72/   82 batches | lr 0.0000003453 | 122.51 ms | loss 0.0016605
# | epoch  97 |    80/   82 batches | lr 0.0000003453 | 122.96 ms | loss 0.0018417
# --------------------------------------------------------------------------------
# | end of epoch  97 | time: 10.15s
# --------------------------------------------------------------------------------
# | epoch  98 |     8/   82 batches | lr 0.0000003280 | 138.51 ms | loss 0.0041147
# | epoch  98 |    16/   82 batches | lr 0.0000003280 | 123.14 ms | loss 0.0022122
# | epoch  98 |    24/   82 batches | lr 0.0000003280 | 123.12 ms | loss 0.0023178
# | epoch  98 |    32/   82 batches | lr 0.0000003280 | 122.22 ms | loss 0.0021590
# | epoch  98 |    40/   82 batches | lr 0.0000003280 | 122.11 ms | loss 0.0017740
# | epoch  98 |    48/   82 batches | lr 0.0000003280 | 122.02 ms | loss 0.0016017
# | epoch  98 |    56/   82 batches | lr 0.0000003280 | 122.14 ms | loss 0.0016059
# | epoch  98 |    64/   82 batches | lr 0.0000003280 | 122.22 ms | loss 0.0016573
# | epoch  98 |    72/   82 batches | lr 0.0000003280 | 122.50 ms | loss 0.0016510
# | epoch  98 |    80/   82 batches | lr 0.0000003280 | 122.51 ms | loss 0.0018402
# --------------------------------------------------------------------------------
# | end of epoch  98 | time: 10.09s
# --------------------------------------------------------------------------------
# | epoch  99 |     8/   82 batches | lr 0.0000003116 | 138.23 ms | loss 0.0041334
# | epoch  99 |    16/   82 batches | lr 0.0000003116 | 122.61 ms | loss 0.0022189
# | epoch  99 |    24/   82 batches | lr 0.0000003116 | 122.89 ms | loss 0.0023001
# | epoch  99 |    32/   82 batches | lr 0.0000003116 | 123.09 ms | loss 0.0021807
# | epoch  99 |    40/   82 batches | lr 0.0000003116 | 122.95 ms | loss 0.0017693
# | epoch  99 |    48/   82 batches | lr 0.0000003116 | 122.82 ms | loss 0.0015608
# | epoch  99 |    56/   82 batches | lr 0.0000003116 | 122.83 ms | loss 0.0016137
# | epoch  99 |    64/   82 batches | lr 0.0000003116 | 122.30 ms | loss 0.0016638
# | epoch  99 |    72/   82 batches | lr 0.0000003116 | 122.55 ms | loss 0.0016416
# | epoch  99 |    80/   82 batches | lr 0.0000003116 | 123.24 ms | loss 0.0018291
# --------------------------------------------------------------------------------
# | end of epoch  99 | time: 10.12s
# --------------------------------------------------------------------------------
# | epoch 100 |     8/   82 batches | lr 0.0000002960 | 139.28 ms | loss 0.0040477
# | epoch 100 |    16/   82 batches | lr 0.0000002960 | 123.44 ms | loss 0.0022175
# | epoch 100 |    24/   82 batches | lr 0.0000002960 | 123.93 ms | loss 0.0022500
# | epoch 100 |    32/   82 batches | lr 0.0000002960 | 123.87 ms | loss 0.0021361
# | epoch 100 |    40/   82 batches | lr 0.0000002960 | 124.19 ms | loss 0.0017897
# | epoch 100 |    48/   82 batches | lr 0.0000002960 | 123.94 ms | loss 0.0015834
# | epoch 100 |    56/   82 batches | lr 0.0000002960 | 123.12 ms | loss 0.0016338
# | epoch 100 |    64/   82 batches | lr 0.0000002960 | 123.50 ms | loss 0.0016491
# | epoch 100 |    72/   82 batches | lr 0.0000002960 | 123.79 ms | loss 0.0016552
# | epoch 100 |    80/   82 batches | lr 0.0000002960 | 123.45 ms | loss 0.0018144
# --------------------------------------------------------------------------------
# | end of epoch 100 | time: 13.50s | valid loss: 0.0002636
# --------------------------------------------------------------------------------

# %%
test_result, truth = forecast_seq(model, train_data)
# Out:
# 24.935197353363037 sec

# %%
test_result = mm_scaler.inverse_transform(test_result.reshape(-1,1))
truth = mm_scaler.inverse_transform(truth.reshape(-1,1))

# %%
print(test_result.shape)
# Out:
# (10537, 1)

# %% [markdown]
# Plot forecasted sequence vs actual

# %%
plt.plot(truth, color='red', alpha=0.7)
plt.plot(test_result, color='blue', linewidth=0.7)
plt.title('Actual vs Forecast')
plt.legend(['Actual', 'Forecast'])
plt.xlabel('Time Steps')
plt.xlim([0,10000])

plt.show()

# %% [markdown]
# Test random sequence

# %%
r = np.random.randint(100000, 160000)
test_forecast = model_forecast(model, csum_logreturn[r: r+10]) # random 10 sequence length

print(f"forecast sequence: {test_forecast}")
print(f"Actual sequence: {csum_logreturn[r: r+11]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 r = np.random.randint(100000, 160000)
# ----> 2 test_forecast = model_forecast(model, csum_logreturn[r: r+10]) # random 10 sequence length
#       4 print(f"forecast sequence: {test_forecast}")
#       5 print(f"Actual sequence: {csum_logreturn[r: r+11]}")
#
# NameError: name 'csum_logreturn' is not defined

# %% [markdown]
# Save model

# %%
torch.save(model.state_dict(), "transformer_ts.pth")

# %% [markdown]
# Load model

# %%
model2 = TransAm() # rename as model2
model2.load_state_dict(torch.load("transformer_ts.pth"))
model2.to(device)
# Out:
# TransAm(
#   (pos_encoder): PositionalEncoding()
#   (encoder_layer): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=250, out_features=250, bias=True)
#     )
#     (linear1): Linear(in_features=250, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=250, bias=True)
#     (norm1): LayerNorm((250,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((250,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=250, out_features=250, bias=True)
#         )
#         (linear1): Linear(in_features=250, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=250, bias=True)
#         (norm1): LayerNorm((250,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((250,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=250, out_features=1, bias=True)
# )

# %% [markdown]
# Testing model on Boeing stock from the same time period

# %%
df2 = pd.read_csv('BA_raw.csv') # Boeing Co stock
close2 = df2['close'].fillna(method = 'ffill')
close2 = np.array(close2)
logreturn2 = np.diff(np.log(close2))

# %%
train_data2, val_data2 = get_data(logreturn2, 0.6)
test2_eval = evaluate(model2, val_data2)
print(f'Test 2 loss: {test2_eval :.5f}')
# Out:
# Test 2 loss: 0.00008

# %%
test_result2, truth2 = forecast_seq(model2, val_data2)

plt.plot(truth2, color='red', alpha=0.7)
plt.plot(test_result2, color='blue', linewidth=0.7)
plt.title('Actual vs Forecast')
plt.legend(['Actual', 'Forecast'])
plt.xlabel('Time Steps')
plt.show()
# Out:
# 125.28154563903809 sec

# %% [markdown]
# Testing model on JPMorgan stock from the same time period

# %%
df3 = pd.read_csv('JPM_raw.csv') # JPMorgan Chase & Co stock
close3 = df3['close'].fillna(method = 'ffill')
close3 = np.array(close3)
logreturn3 = np.diff(np.log(close3))

# %%
train_data3, val_data3 = get_data(logreturn3, 0.6)
test3_eval = evaluate(model2, val_data3)
print(f'Test 3 loss: {test3_eval :.5f}')
# Out:
# Test 3 loss: 0.00001

# %%
test_result3, truth3 = forecast_seq(model2, val_data3)

plt.plot(truth3, color='red', alpha=0.7)
plt.plot(test_result3, color='blue', linewidth=0.7)
plt.title('Actual vs Forecast')
plt.legend(['Actual', 'Forecast'])
plt.xlabel('Time Steps')
plt.show()
# Out:
# 127.89451098442078 sec

# %% [markdown]
# ## Conclusion
# Transformer model is able to train on a longer sequence compared to LSTM models (5 vs 10)
# Transformer model also trained faster, given the longer sequence length, and took lesser epochs to train the model
#
# ### Data Transforming and Normalising
# Advantages of using cumulative sum of log returns compared to min-max scaler in normalising stocks prices,
# create better standardisation across stocks
# Training data augmentation allowed model to be trained on wider data points, resulting in the model generalising well across unseen data from test 2 and test 3
# Previous testing without data augmentation had models underperforming with higher loss
