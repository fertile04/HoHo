# %%
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from torch import nn, Tensor, TupleType

from torch.nn import Transformer
from torch.nn import Transformer_1dcnn





from torch.utils.data import TensorDataset, DataLoader, Dataset, random_split
from torch.autograd import Variable
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split  

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
mm_scaler = MinMaxScaler()

class StrideDataset(Dataset):
    def __init__(self, file_path, enc_seq_len, target_seq_len, x_size, stride=5):
        
        df = pd.read_csv(file_path)
        self.length = len(df) - x_size
        
        self.soc = df.iloc[x_size:, 20:21].values #SoC
        self.soc = self.soc.squeeze()
        self.soc = mm_scaler.fit_transform(self.soc.reshape(-1, 1))
        self.soc = self.soc.squeeze()
        # plt.plot(self.soc[0:50])

        self.src_v = df.iloc[x_size:, 7:8].values #V
        self.src_v = self.src_v.squeeze()
        self.src_v = mm_scaler.fit_transform(self.src_v.reshape(-1, 1))
        self.src_v = self.src_v.squeeze()

        self.src_c = df.iloc[x_size:, 6:7].values #I
        self.src_c = self.src_c.squeeze()

        self.new_src_c = []

        for i in range(self.length):
            if i == 0:
                self.new_src_c.append(self.src_c[i])
            else:
                self.new_src_c.append(self.src_c[i] - self.src_c[i-1])

        self.new_src_c = np.array(self.new_src_c)

        self.new_src_c = mm_scaler.fit_transform(self.new_src_c.reshape(-1, 1))
        self.new_src_c = self.new_src_c.squeeze()
        # plt.plot(self.new_src_c[0:50])


        self.length = len(df) - x_size

        num_samples = (self.length - enc_seq_len - target_seq_len) // stride + 1 #stride씩 움직일 때 생기는 총 sample 개수
        
        src_v = np.zeros([enc_seq_len, num_samples])
        new_src_c = np.zeros([enc_seq_len, num_samples])
        trg = np.zeros([target_seq_len, num_samples])

        
        for i in np.arange(num_samples):
            start_x = stride*i
            end_x = start_x + enc_seq_len
            src_v[:,i] = self.src_v[start_x:end_x]
            new_src_c[:,i] = self.new_src_c[start_x:end_x]

            start_y = stride*i + enc_seq_len
            end_y = start_y + target_seq_len
            trg[:,i] = self.soc[start_y:end_y]

        src_v = src_v.reshape(src_v.shape[0], src_v.shape[1], 1).transpose((1,0,2))
        new_src_c = new_src_c.reshape(new_src_c.shape[0], new_src_c.shape[1], 1).transpose((1,0,2))
        trg = trg.reshape(trg.shape[0], trg.shape[1], 1).transpose((1,0,2))

        print(src_v.shape)
        self.src_v = src_v
        print(new_src_c.shape)
        self.new_src_c = new_src_c
        self.trg = trg

        self.len = len(src_v)

    def __getitem__(self, i):
        return self.src_v[i], self.new_src_c[i], self.trg[i, :-1], self.trg[i, 1:]
    
    def __len__(self):
        return self.len

# %%
# mm_scaler = MinMaxScaler()

# class StrideDataset(Dataset):
#     def __init__(self, file_path, enc_seq_len, target_seq_len, x_size, stride=5):
#         df = pd.read_csv(file_path)
        
#         self.soc = df.iloc[x_size:, 20:21].values #SoC
#         self.soc = self.soc.squeeze()
#         self.soc = mm_scaler.fit_transform(self.soc.reshape(-1, 1))
#         self.soc = self.soc.squeeze()

#         self.src_v = df.iloc[x_size:, 7:8].values #V
#         self.src_v = self.src_v.squeeze()
#         self.src_v = mm_scaler.fit_transform(self.src_v.reshape(-1, 1))
#         self.src_v = self.src_v.squeeze()

#         self.src_c = df.iloc[x_size:, 6:7].values #I
#         self.src_c = self.src_c.squeeze()
#         self.src_c = mm_scaler.fit_transform(self.src_c.reshape(-1, 1))
#         self.src_c = self.src_c.squeeze()


#         self.length = len(df) - x_size

#         num_samples = (self.length - enc_seq_len - target_seq_len) // stride + 1 #stride씩 움직일 때 생기는 총 sample 개수
        
#         src_v = np.zeros([enc_seq_len, num_samples])
#         src_c = np.zeros([enc_seq_len, num_samples])
#         trg = np.zeros([target_seq_len, num_samples])

        
#         for i in np.arange(num_samples):
#             start_x = stride*i
#             end_x = start_x + enc_seq_len
#             src_v[:,i] = self.src_v[start_x:end_x]
#             src_c[:,i] = self.src_c[start_x:end_x]

#             start_y = stride*i + enc_seq_len
#             end_y = start_y + target_seq_len
#             trg[:,i] = self.soc[start_y:end_y]

#         src_v = src_v.reshape(src_v.shape[0], src_v.shape[1], 1).transpose((1,0,2))
#         src_c = src_c.reshape(src_c.shape[0], src_c.shape[1], 1).transpose((1,0,2))
#         trg = trg.reshape(trg.shape[0], trg.shape[1], 1).transpose((1,0,2))

#         print(src_v.shape)
#         self.src_v = src_v
#         print(src_c.shape)
#         self.src_c = src_c
#         self.trg = trg

#         self.len = len(src_v)

#     def __getitem__(self, i):
#         return self.src_v[i], self.src_c[i], self.trg[i, :-1], self.trg[i, 1:]
    
#     def __len__(self):
#         return self.len

# %%
class CustomDataset(Dataset):
    def __init__(self, file_path, x_size):
        df = pd.read_csv(file_path)
        #print(df.isnull().sum())

        self.x = df.iloc[x_size:, 6:10].values
        #self.x = np.reshape(x, (x.shape[0], 1, x.shape[1]))
        self.y = df.iloc[x_size:, 20:21].values
        
        self.length = len(df) - x_size

    def __getitem__(self, index):
        # x = torch.FloatTensor([self.x[index]])
        # y = torch.FloatTensor([self.y[index]])
        # return x, y
        feature = torch.FloatTensor([self.x[index]])
        label = torch.FloatTensor(self.y[index])

        return feature, label

    def __len__(self):
        return self.length

# %%
train_dataset_1 = StrideDataset("DST_80.csv", 50, 20, 1919, stride=5)
train_dataset_2 = StrideDataset("US06_80.csv", 50, 20, 1207, stride=5)
# train_dataset_1 = StrideDataset("FUDS_80.csv", 50, 20, 2586, stride=5)
# train_dataset_2 = StrideDataset("BJDST_80.csv", 50, 20, 1226, stride=5)

train_dataset = torch.utils.data.ConcatDataset([train_dataset_1, train_dataset_2])
# train_dataset = train_dataset_2


train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=False)
# dataset_d = CustomDataset("DST_80.csv", 1919)
# Out:
# (2114, 50, 1)
# (2114, 50, 1)
# (2125, 50, 1)
# (2125, 50, 1)

# %%
class TFModel(nn.Module):
    def __init__(self, d_model, nhead, nhid, nlayers, dropout=0.5):
        super(TFModel, self).__init__()

        # self.transformer = Transformer(d_model=d_model, nhead=nhead, dim_feedforward=nhid, num_encoder_layers=nlayers, num_decoder_layers=nlayers,dropout=dropout)
        
        # self.linear = nn.Linear(d_model, 1)
        # self.pos_encoder = PositionalEncoding(d_model, dropout)

        # self.encoder = nn.Linear(1, d_model)

        self.coder_in = nn.Linear(1,d_model)
        
        self.coder_in2 = nn.Sequential(
            nn.Linear(1, 64),
            nn.ReLU(),
            nn.Linear(64,128),
            nn.ReLU(),
            nn.Linear(128, d_model)
        )
        
        self.conv_in = nn.Sequential(
            nn.Conv1d(1, d_model, kernel_size=15),
            nn.Softmax(dim=1),
            nn.Linear(50-15+1, 50) #src-ker+1, src
        )
        
        # self.conv_in_dec = nn.Sequential(
        #     nn.Conv1d(1,d_model,kernel_size=15),
        #     nn.Softmax(dim=1),
        #     nn.Linear(20-15, 20-1) #dec-ker, dec-1
        # )
        
        
        # self.conv_out = nn.Sequential(
        #     nn.Conv1d(d_model,50,kernel_size=5,stride=3),
        #     #nn.ReLU(),
        #     nn.Conv1d(50,1,kernel_size=3,stride=1),
        #     #nn.ReLU(),
        #     nn.Linear(3,30),
        #     #nn.ReLU(),
        #     nn.Linear(30,19)
        # )

        self.coder_pos = PositionalEncoding(d_model, dropout)

        self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=nhid, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=nlayers)
        
        #
        self.encoder_layer_1dcnn = nn.TransformerEncoderLayer_1dcnn(d_model=d_model, nhead=nhead, dim_feedforward=nhid, dropout=dropout)
        self.transformer_encoder_1dcnn = nn.TransformerEncoder_1dcnn(self.encoder_layer_1dcnn, num_layers=nlayers)
        # #


        self.con_lin = nn.Linear(d_model*2, d_model)

        self.decoder_layer = nn.TransformerDecoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=nhid, dropout=dropout)
        self.transformer_decoder = nn.TransformerDecoder(self.decoder_layer, num_layers=nlayers) #(target, memory) // memort->인코더에서 나온 컨텍스트벡터?
        #
        self.decoder_layer_1dcnn = nn.TransformerDecoderLayer_1dcnn(d_model=d_model, nhead=nhead, dim_feedforward=nhid, dropout=dropout)
        self.transformer_decoder_1dcnn = nn.TransformerDecoder_1dcnn(self.decoder_layer_1dcnn, num_layers=nlayers)
        # #
        
        

        self.linear = nn.Sequential(
            nn.Linear(d_model, 1)
        )
        
        self.linear2 = nn.Sequential(
            nn.Linear(d_model, 128),
            nn.ReLU(),
            nn.Linear(128,64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
        
        # self.linear_in = nn.Linear(1, d_model)
        
        # self.new = nn.Sequential(
        #     nn.Linear(d_model, d_model),
        #     nn.ReLU(),
        #     nn.Linear(d_model,d_model)
        # )
        

    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    #def forward(self, src, tgt, srcmask, tgtmask):
    def forward(self, src_v, src_c, tgt_s, src_mask_v, src_mask_c, tgtmask):
        src_v = self.coder_in(src_v)
        # src_v = self.coder_in2(src_v)
        # src_v = self.conv_in(src_v.transpose(2,1)).transpose(2,1)
        src_v = self.coder_pos(src_v)



        con_v = self.transformer_encoder(src_v.transpose(0,1), src_mask_v).transpose(0,1)  #-> 그냥
        # con_v = self.transformer_encoder_1dcnn(src_v.transpose(0,1), src_mask_v) #-> 인코더 ff 1dcnn
        
        

    
        

        # flag = con
        #print(con.shape)
        
        con = con_v
        #print(con.shape)
        
        
        #print(tgt_s.shape)
        tgt_s = self.coder_in(tgt_s)
        # tgt_s = self.conv_in_dec(tgt_s.transpose(2,1)).transpose(2,1)
        tgt_s = self.coder_pos(tgt_s)
        
        
        tgt = self.transformer_decoder(tgt_s.transpose(0,1), con.transpose(0,1)).transpose(0,1)
        # tgt = self.transformer_decoder_1dcnn(tgt_s.transpose(0,1), con.transpose(0,1)).transpose(0,1)
        # print(tgt.shape)
        tgt = self.linear(tgt) #이거중
        # tgt = self.linear2(tgt)
        # tgt = self.conv_out(tgt.transpose(2,1)).transpose(2,1)

        return tgt

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

def gen_attention_mask(x):
    mask = torch.eq(x, 0)
    return mask

# %%
lr = 0.00003
model = TFModel(256, 8, 512, 4, 0.1).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

# %%
from torchsummaryX import summary

batch_size = 256
src_seq_len = 50
tgt_seq_len = 19
src_feature_dim = 1
src_mask_dim = 50
tgt_mask_dim = 19

# tu1 = [[[0 for i in range(2048)]  for j in range(50)] for k in range(50) ]
# tu = tuple(tu1)

src_v = torch.zeros(batch_size, src_seq_len,src_feature_dim).to(device)
src_c = torch.zeros(batch_size, src_seq_len,src_feature_dim).to(device)
tgt_s = torch.zeros(batch_size, tgt_seq_len,src_feature_dim).to(device)
src_mask_v = torch.zeros(2048,src_mask_dim,src_mask_dim).to(device)
src_mask_c = torch.zeros(2048,src_mask_dim,src_mask_dim).to(device)
tgtmask = torch.rand(batch_size,tgt_mask_dim,tgt_mask_dim).to(device)

# src_v = (256,50,1)
# src_c = (256,50,1)
# tgt_s = (256,19,1)
# src_mask_v = (50,50,)
# src_mask_c = (50,50,)


# summary(model, (torch.rand((src_seq_len,src_feature_dim)), torch.rand((src_seq_len,src_feature_dim)), torch.rand((tgt_seq_len,src_feature_dim)), torch.rand((src_seq_len,src_mask_dim)), torch.rand((src_seq_len,src_mask_dim))) )
summary(model, src_v,src_v,tgt_s,src_mask_v,src_mask_c,tgtmask)
# Out:
# ==================================================================================================
#                                                  Kernel Shape    Output Shape  \
# Layer
# 0_coder_in                                           [1, 256]  [256, 50, 256]
# 1_coder_pos.Dropout_dropout                                 -  [256, 50, 256]
# 2_transformer_encoder.layers.0.Dropout_dropout1             -  [50, 256, 256]
# 3_transformer_encoder.layers.0.LayerNorm_norm1          [256]  [50, 256, 256]
# 4_transformer_encoder.layers.0.Linear_linear1      [256, 512]  [50, 256, 512]
# 5_transformer_encoder.layers.0.Dropout_dropout              -  [50, 256, 512]
# 6_transformer_encoder.layers.0.Linear_linear2      [512, 256]  [50, 256, 256]
# 7_transformer_encoder.layers.0.Dropout_dropout2             -  [50, 256, 256]
# 8_transformer_encoder.layers.0.LayerNorm_norm2          [256]  [50, 256, 256]
# 9_transformer_encoder.layers.1.Dropout_dropout1             -  [50, 256, 256]
# 10_transformer_encoder.layers.1.LayerNorm_norm1         [256]  [50, 256, 256]
# 11_transformer_encoder.layers.1.Linear_linear1     [256, 512]  [50, 256, 512]
# 12_transformer_encoder.layers.1.Dropout_dropout             -  [50, 256, 512]
# 13_transformer_encoder.layers.1.Linear_linear2     [512, 256]  [50, 256, 256]
# 14_transformer_encoder.layers.1.Dropout_dropout2            -  [50, 256, 256]
# 15_transformer_encoder.layers.1.LayerNorm_norm2         [256]  [50, 256, 256]
# 16_transformer_encoder.layers.2.Dropout_dropout1            -  [50, 256, 256]
# 17_transformer_encoder.layers.2.LayerNorm_norm1         [256]  [50, 256, 256]
# 18_transformer_encoder.layers.2.Linear_linear1     [256, 512]  [50, 256, 512]
# 19_transformer_encoder.layers.2.Dropout_dropout             -  [50, 256, 512]
# 20_transformer_encoder.layers.2.Linear_linear2     [512, 256]  [50, 256, 256]
# 21_transformer_encoder.layers.2.Dropout_dropout2            -  [50, 256, 256]
# 22_transformer_encoder.layers.2.LayerNorm_norm2         [256]  [50, 256, 256]
# 23_transformer_encoder.layers.3.Dropout_dropout1            -  [50, 256, 256]
# 24_transformer_encoder.layers.3.LayerNorm_norm1         [256]  [50, 256, 256]
# 25_transformer_encoder.layers.3.Linear_linear1     [256, 512]  [50, 256, 512]
# 26_transformer_encoder.layers.3.Dropout_dropout             -  [50, 256, 512]
# 27_transformer_encoder.layers.3.Linear_linear2     [512, 256]  [50, 256, 256]
# 28_transformer_encoder.layers.3.Dropout_dropout2            -  [50, 256, 256]
# 29_transformer_encoder.layers.3.LayerNorm_norm2         [256]  [50, 256, 256]
# 30_coder_in                                          [1, 256]  [256, 19, 256]
# 31_coder_pos.Dropout_dropout                                -  [256, 19, 256]
# 32_transformer_decoder.layers.0.Dropout_dropout1            -  [19, 256, 256]
# 33_transformer_decoder.layers.0.LayerNorm_norm1         [256]  [19, 256, 256]
# 34_transformer_decoder.layers.0.Dropout_dropout2            -  [19, 256, 256]
# 35_transformer_decoder.layers.0.LayerNorm_norm2         [256]  [19, 256, 256]
# 36_transformer_decoder.layers.0.Linear_linear1     [256, 512]  [19, 256, 512]
# 37_transformer_decoder.layers.0.Dropout_dropout             -  [19, 256, 512]
# 38_transformer_decoder.layers.0.Linear_linear2     [512, 256]  [19, 256, 256]
# 39_transformer_decoder.layers.0.Dropout_dropout3            -  [19, 256, 256]
# 40_transformer_decoder.layers.0.LayerNorm_norm3         [256]  [19, 256, 256]
# 41_transformer_decoder.layers.1.Dropout_dropout1            -  [19, 256, 256]
# 42_transformer_decoder.layers.1.LayerNorm_norm1         [256]  [19, 256, 256]
# 43_transformer_decoder.layers.1.Dropout_dropout2            -  [19, 256, 256]
# 44_transformer_decoder.layers.1.LayerNorm_norm2         [256]  [19, 256, 256]
# 45_transformer_decoder.layers.1.Linear_linear1     [256, 512]  [19, 256, 512]
# 46_transformer_decoder.layers.1.Dropout_dropout             -  [19, 256, 512]
# 47_transformer_decoder.layers.1.Linear_linear2     [512, 256]  [19, 256, 256]
# 48_transformer_decoder.layers.1.Dropout_dropout3            -  [19, 256, 256]
# 49_transformer_decoder.layers.1.LayerNorm_norm3         [256]  [19, 256, 256]
# 50_transformer_decoder.layers.2.Dropout_dropout1            -  [19, 256, 256]
# 51_transformer_decoder.layers.2.LayerNorm_norm1         [256]  [19, 256, 256]
# 52_transformer_decoder.layers.2.Dropout_dropout2            -  [19, 256, 256]
# 53_transformer_decoder.layers.2.LayerNorm_norm2         [256]  [19, 256, 256]
# 54_transformer_decoder.layers.2.Linear_linear1     [256, 512]  [19, 256, 512]
# 55_transformer_decoder.layers.2.Dropout_dropout             -  [19, 256, 512]
# 56_transformer_decoder.layers.2.Linear_linear2     [512, 256]  [19, 256, 256]
# 57_transformer_decoder.layers.2.Dropout_dropout3            -  [19, 256, 256]
# 58_transformer_decoder.layers.2.LayerNorm_norm3         [256]  [19, 256, 256]
# 59_transformer_decoder.layers.3.Dropout_dropout1            -  [19, 256, 256]
# 60_transformer_decoder.layers.3.LayerNorm_norm1         [256]  [19, 256, 256]
# 61_transformer_decoder.layers.3.Dropout_dropout2            -  [19, 256, 256]
# 62_transformer_decoder.layers.3.LayerNorm_norm2         [256]  [19, 256, 256]
# 63_transformer_decoder.layers.3.Linear_linear1     [256, 512]  [19, 256, 512]
# 64_transformer_decoder.layers.3.Dropout_dropout             -  [19, 256, 512]
# 65_transformer_decoder.layers.3.Linear_linear2     [512, 256]  [19, 256, 256]
# 66_transformer_decoder.layers.3.Dropout_dropout3            -  [19, 256, 256]
# 67_transformer_decoder.layers.3.LayerNorm_norm3         [256]  [19, 256, 256]
# 68_linear.Linear_0                                   [256, 1]    [256, 19, 1]
#
#                                                     Params Mult-Adds
# Layer
# 0_coder_in                                           512.0     256.0
# 1_coder_pos.Dropout_dropout                              -         -
# 2_transformer_encoder.layers.0.Dropout_dropout1          -         -
# 3_transformer_encoder.layers.0.LayerNorm_norm1       512.0     256.0
# 4_transformer_encoder.layers.0.Linear_linear1     131.584k  131.072k
# 5_transformer_encoder.layers.0.Dropout_dropout           -         -
# 6_transformer_encoder.layers.0.Linear_linear2     131.328k  131.072k
# 7_transformer_encoder.layers.0.Dropout_dropout2          -         -
# 8_transformer_encoder.layers.0.LayerNorm_norm2       512.0     256.0
# 9_transformer_encoder.layers.1.Dropout_dropout1          -         -
# 10_transformer_encoder.layers.1.LayerNorm_norm1      512.0     256.0
# 11_transformer_encoder.layers.1.Linear_linear1    131.584k  131.072k
# 12_transformer_encoder.layers.1.Dropout_dropout          -         -
# 13_transformer_encoder.layers.1.Linear_linear2    131.328k  131.072k
# 14_transformer_encoder.layers.1.Dropout_dropout2         -         -
# 15_transformer_encoder.layers.1.LayerNorm_norm2      512.0     256.0
# 16_transformer_encoder.layers.2.Dropout_dropout1         -         -
# 17_transformer_encoder.layers.2.LayerNorm_norm1      512.0     256.0
# 18_transformer_encoder.layers.2.Linear_linear1    131.584k  131.072k
# 19_transformer_encoder.layers.2.Dropout_dropout          -         -
# 20_transformer_encoder.layers.2.Linear_linear2    131.328k  131.072k
# 21_transformer_encoder.layers.2.Dropout_dropout2         -         -
# 22_transformer_encoder.layers.2.LayerNorm_norm2      512.0     256.0
# 23_transformer_encoder.layers.3.Dropout_dropout1         -         -
# 24_transformer_encoder.layers.3.LayerNorm_norm1      512.0     256.0
# 25_transformer_encoder.layers.3.Linear_linear1    131.584k  131.072k
# 26_transformer_encoder.layers.3.Dropout_dropout          -         -
# 27_transformer_encoder.layers.3.Linear_linear2    131.328k  131.072k
# 28_transformer_encoder.layers.3.Dropout_dropout2         -         -
# 29_transformer_encoder.layers.3.LayerNorm_norm2      512.0     256.0
# 30_coder_in                                              -     256.0
# 31_coder_pos.Dropout_dropout                             -         -
# 32_transformer_decoder.layers.0.Dropout_dropout1         -         -
# 33_transformer_decoder.layers.0.LayerNorm_norm1      512.0     256.0
# 34_transformer_decoder.layers.0.Dropout_dropout2         -         -
# 35_transformer_decoder.layers.0.LayerNorm_norm2      512.0     256.0
# 36_transformer_decoder.layers.0.Linear_linear1    131.584k  131.072k
# 37_transformer_decoder.layers.0.Dropout_dropout          -         -
# 38_transformer_decoder.layers.0.Linear_linear2    131.328k  131.072k
# 39_transformer_decoder.layers.0.Dropout_dropout3         -         -
# 40_transformer_decoder.layers.0.LayerNorm_norm3      512.0     256.0
# 41_transformer_decoder.layers.1.Dropout_dropout1         -         -
# 42_transformer_decoder.layers.1.LayerNorm_norm1      512.0     256.0
# 43_transformer_decoder.layers.1.Dropout_dropout2         -         -
# 44_transformer_decoder.layers.1.LayerNorm_norm2      512.0     256.0
# 45_transformer_decoder.layers.1.Linear_linear1    131.584k  131.072k
# 46_transformer_decoder.layers.1.Dropout_dropout          -         -
# 47_transformer_decoder.layers.1.Linear_linear2    131.328k  131.072k
# 48_transformer_decoder.layers.1.Dropout_dropout3         -         -
# 49_transformer_decoder.layers.1.LayerNorm_norm3      512.0     256.0
# 50_transformer_decoder.layers.2.Dropout_dropout1         -         -
# 51_transformer_decoder.layers.2.LayerNorm_norm1      512.0     256.0
# 52_transformer_decoder.layers.2.Dropout_dropout2         -         -
# 53_transformer_decoder.layers.2.LayerNorm_norm2      512.0     256.0
# 54_transformer_decoder.layers.2.Linear_linear1    131.584k  131.072k
# 55_transformer_decoder.layers.2.Dropout_dropout          -         -
# 56_transformer_decoder.layers.2.Linear_linear2    131.328k  131.072k
# 57_transformer_decoder.layers.2.Dropout_dropout3         -         -
# 58_transformer_decoder.layers.2.LayerNorm_norm3      512.0     256.0
# 59_transformer_decoder.layers.3.Dropout_dropout1         -         -
# 60_transformer_decoder.layers.3.LayerNorm_norm1      512.0     256.0
# 61_transformer_decoder.layers.3.Dropout_dropout2         -         -
# 62_transformer_decoder.layers.3.LayerNorm_norm2      512.0     256.0
# 63_transformer_decoder.layers.3.Linear_linear1    131.584k  131.072k
# 64_transformer_decoder.layers.3.Dropout_dropout          -         -
# 65_transformer_decoder.layers.3.Linear_linear2    131.328k  131.072k
# 66_transformer_decoder.layers.3.Dropout_dropout3         -         -
# 67_transformer_decoder.layers.3.LayerNorm_norm3      512.0     256.0
# 68_linear.Linear_0                                   257.0     256.0
# --------------------------------------------------------------------------------------------------
#                          Totals
# Total params          2.114305M
# Trainable params      2.114305M
# Non-trainable params        0.0
# Mult-Adds              2.10304M
# ==================================================================================================
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torchsummaryX\torchsummaryX.py:101: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_sum = df.sum()
#                                                  Kernel Shape    Output Shape  \
# Layer
# 0_coder_in                                           [1, 256]  [256, 50, 256]
# 1_coder_pos.Dropout_dropout                                 -  [256, 50, 256]
# 2_transformer_encoder.layers.0.Dropout_dropout1             -  [50, 256, 256]
# 3_transformer_encoder.layers.0.LayerNorm_norm1          [256]  [50, 256, 256]
# 4_transformer_encoder.layers.0.Linear_linear1      [256, 512]  [50, 256, 512]
# ...                                                       ...             ...
# 64_transformer_decoder.layers.3.Dropout_dropout             -  [19, 256, 512]
# 65_transformer_decoder.layers.3.Linear_linear2     [512, 256]  [19, 256, 256]
# 66_transformer_decoder.layers.3.Dropout_dropout3            -  [19, 256, 256]
# 67_transformer_decoder.layers.3.LayerNorm_norm3         [256]  [19, 256, 256]
# 68_linear.Linear_0                                   [256, 1]    [256, 19, 1]
#
#                                                     Params  Mult-Adds
# Layer
# 0_coder_in                                           512.0      256.0
# 1_coder_pos.Dropout_dropout                            NaN        NaN
# 2_transformer_encoder.layers.0.Dropout_dropout1        NaN        NaN
# 3_transformer_encoder.layers.0.LayerNorm_norm1       512.0      256.0
# 4_transformer_encoder.layers.0.Linear_linear1     131584.0   131072.0
# ...                                                    ...        ...
# 64_transformer_decoder.layers.3.Dropout_dropout        NaN        NaN
# 65_transformer_decoder.layers.3.Linear_linear2    131328.0   131072.0
# 66_transformer_decoder.layers.3.Dropout_dropout3       NaN        NaN
# 67_transformer_decoder.layers.3.LayerNorm_norm3      512.0      256.0
# 68_linear.Linear_0                                   257.0      256.0
#
# [69 rows x 4 columns]

# %%
epoch = 4000
model.train()
progress = tqdm(range(epoch))

loss_arr = list()


for i in progress:
    batchloss = 0.0
    for (inputs_v, inputs_c, dec_inputs, outputs) in train_dataloader:
        optimizer.zero_grad()
        #print(inputs_v.shape[1])
        src_mask_v = model.generate_square_subsequent_mask(inputs_v.shape[1]).to(device)
        src_mask_c = model.generate_square_subsequent_mask(inputs_c.shape[1]).to(device)
        #print(dec_inputs.shape[1])
        tgt_mask = model.generate_square_subsequent_mask(dec_inputs.shape[1]).to(device)
        
        result = model(inputs_v.float().to(device), inputs_c.float().to(device), dec_inputs.float().to(device), src_mask_v, src_mask_c, tgt_mask)
        
        #loss = criterion(result.permute(1,0,2), outputs.float().to(device))
        loss = criterion(result, outputs.float().to(device))
        
        
        loss.backward()
        optimizer.step()
        batchloss += loss
    
        
    loss_arr.append((batchloss.cpu().item() / len(train_dataloader)))
    progress.set_description("loss: {:0.6f}".format(batchloss.cpu().item() / len(train_dataloader)))




    # for i in progress:
    # batchloss = 0.0

    # for (inputs, tgt, tgt_y) in train_dataloader:
    #     optimizer.zero_grad()

    #     result = model(src.float().to(device), tgt.float().to(device), src_mask, tgt_mask)
    #     loss = loss_func(result, tgt_y.float().to(device))

    #     loss.backward()
    #     optimizer.step()
    #     batchloss += loss
    
    # progress.set_description("{:0.5f}".format(batchloss.cpu().item() / len(train_dataloader)))#??
# Out:
# loss: 0.004921:   1%|          | 21/4000 [00:17<56:49,  1.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 24
#      20 #loss = criterion(result.permute(1,0,2), outputs.float().to(device))
#      21 loss = criterion(result, outputs.float().to(device))
# ---> 24 loss.backward()
#      25 optimizer.step()
#      26 batchloss += loss
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
plt.plot(loss_arr[500:4000], label="loss")
# print(loss_arr[1500])
# print(loss_arr[2400])

# %%
eval_dataset = StrideDataset("FUDS_80.csv", 50, 20, 2586, stride=1)
# eval_dataset = StrideDataset("BJDST_80.csv", 50, 20, 1226, stride=1)
# eval_dataset = StrideDataset("DST_80.csv", 50, 20, 1919, stride=1)
# eval_dataset = StrideDataset("US06_80.csv", 50, 20, 1207, stride=1)
eval_dataloader = DataLoader(eval_dataset, batch_size=256, shuffle=False, drop_last=False)

# 
dataset_d = CustomDataset("FUDS_80.csv", 2586)
# dataset_d = CustomDataset("BJDST_80.csv", 1226)
# dataset_d = CustomDataset("DST_80.csv", 1919)
# dataset_d = CustomDataset("US06_80.csv", 1207)


predictions_zerosum = torch.zeros(69)
predictions_zerosum.shape
predictions_zerosum

model.eval()

predictions = torch.Tensor(0)
actual = torch.Tensor(0)
cnt=0

with torch.no_grad():
    for (inputs_v, inputs_c, dec_inputs, outputs) in eval_dataloader:
        src_mask_v = model.generate_square_subsequent_mask(inputs_v.shape[1]).to(device)
        src_mask_c = model.generate_square_subsequent_mask(inputs_c.shape[1]).to(device)
        tgt_mask = model.generate_square_subsequent_mask(dec_inputs.shape[1]).to(device)
        
        output = model(inputs_v.float().to(device), inputs_c.float().to(device), dec_inputs.float().to(device), src_mask_v, src_mask_c, tgt_mask)
        output = output.permute(1,0,2)
        
        cnt=cnt+1
        predictions = torch.cat((predictions, output[-1].view(-1).cpu()), 0) # view(-1) => 1차원으로 바꾼다 생각
        actual = torch.cat((actual, outputs[-1].view(-1).cpu()), 0)


print(predictions.shape)
print(dataset_d.y.shape)
print(cnt)

predictions = torch.concat((predictions_zerosum, predictions),0)

predictions = predictions * 80.0

plt.figure(figsize=(10,4))
plt.plot(dataset_d.y[69:], color='red', alpha=0.7)
plt.plot(predictions[69:], color='blue', linewidth=0.7)
plt.title('Actual vs Forecast')
plt.legend(['Actual', 'Forecast'])
plt.xlabel('Time Steps')
# plt.xlim([2800,3000])
# plt.ylim([56.5,60.5])


from sklearn.metrics import mean_absolute_error, mean_squared_error

print(dataset_d.y.shape)
print(predictions.shape)

print("mae : ", mean_absolute_error(dataset_d.y[69:10000], predictions[69:10000]))
print("mse : ", mean_squared_error(dataset_d.y[69:10000], predictions[69:10000]))
print("rmse : ", np.sqrt(mean_squared_error(dataset_d.y[69:10000], predictions[69:10000])))
# Out:
# (11026, 50, 1)
# (11026, 50, 1)
# torch.Size([11026])
# (11095, 1)
# 44
# (11095, 1)
# torch.Size([11095])
# mae :  0.35572219960489637
# mse :  0.17606718981255237
# rmse :  0.4196036103426094

# %%
# eval_dataset = StrideDataset("FUDS_80.csv", 50, 20, 2586, stride=1)
eval_dataset = StrideDataset("BJDST_80.csv", 50, 20, 1226, stride=1)
# eval_dataset = StrideDataset("DST_80.csv", 50, 20, 1919, stride=1)
# eval_dataset = StrideDataset("US06_80.csv", 50, 20, 1207, stride=1)
eval_dataloader = DataLoader(eval_dataset, batch_size=256, shuffle=False, drop_last=False)

# 
# dataset_d = CustomDataset("FUDS_80.csv", 2586)
dataset_d = CustomDataset("BJDST_80.csv", 1226)
# dataset_d = CustomDataset("DST_80.csv", 1919)
# dataset_d = CustomDataset("US06_80.csv", 1207)


predictions_zerosum = torch.zeros(69)
predictions_zerosum.shape
predictions_zerosum

model.eval()

predictions = torch.Tensor(0)
actual = torch.Tensor(0)
cnt=0

with torch.no_grad():
    for (inputs_v, inputs_c, dec_inputs, outputs) in eval_dataloader:
        src_mask_v = model.generate_square_subsequent_mask(inputs_v.shape[1]).to(device)
        src_mask_c = model.generate_square_subsequent_mask(inputs_c.shape[1]).to(device)
        tgt_mask = model.generate_square_subsequent_mask(dec_inputs.shape[1]).to(device)
        
        output = model(inputs_v.float().to(device), inputs_c.float().to(device), dec_inputs.float().to(device), src_mask_v, src_mask_c, tgt_mask)
        output = output.permute(1,0,2)
        
        cnt=cnt+1
        predictions = torch.cat((predictions, output[-1].view(-1).cpu()), 0) # view(-1) => 1차원으로 바꾼다 생각
        actual = torch.cat((actual, outputs[-1].view(-1).cpu()), 0)


print(predictions.shape)
print(dataset_d.y.shape)
print(cnt)

predictions = torch.concat((predictions_zerosum, predictions),0)

predictions = predictions * 80.0

plt.figure(figsize=(10,4))
plt.plot(dataset_d.y[69:], color='red', alpha=0.7)
plt.plot(predictions[69:], color='blue', linewidth=0.7)
plt.title('Actual vs Forecast')
plt.legend(['Actual', 'Forecast'])
plt.xlabel('Time Steps')
# plt.xlim([2800,3000])
# plt.ylim([56.5,60.5])


from sklearn.metrics import mean_absolute_error, mean_squared_error

print(dataset_d.y.shape)
print(predictions.shape)

print("mae : ", mean_absolute_error(dataset_d.y[69:10000], predictions[69:10000]))
print("mse : ", mean_squared_error(dataset_d.y[69:10000], predictions[69:10000]))
print("rmse : ", np.sqrt(mean_squared_error(dataset_d.y[69:10000], predictions[69:10000])))
# Out:
# (11142, 50, 1)
# (11142, 50, 1)
# torch.Size([11142])
# (11211, 1)
# 44
# (11211, 1)
# torch.Size([11211])
# mae :  0.4371174173213406
# mse :  0.2440883775316723
# rmse :  0.4940530108517428
